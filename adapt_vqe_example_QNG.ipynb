# %% [markdown]
# # Example workflow using PBE and ADAPT-VQE and QNG(SPSA)
#
# > PBE = Projection-Based Embedding
#
# > ADAPT-VQE = Adaptive Derivative Assembled Pseudo-Trotter Variational Quantum Eigensolver
#
# > QNG = Quantum Natural Gradient
#
# - Choose a molecule to simulate, in this case $\mathrm{H}_2\mathrm{O}$
# - Embed some subdomain of the molecule, in this case one of the $\mathrm{O} - \mathrm{H}$ bonds.
# - Get the various objects required for a quantum simulation:
#     - The Hamiltonian whose ground state we are aiming to estimate;
#     - The Hartree-Fock state to use as reference to initialize our circuits;
#     - The cluster operator to define the excitations used in the ansatz circuit.
# - Then, run an ADAPT-VQE routine to iteratively build an ansatz circuit -- this approach has some favourable properties, for example we can control how deep the circuits get and it should be resilient to barren plateaus, since each ADAPT cycle is warm-started from the solution of the previous iteration.
# - We can play different optimization methods like QNG and QNG-SPSA for faster convergence and less shots.
# - We can also play various optimization tricks on the resulting circuits (e.g. with ZX calculus).
#
# ### We go through each of these steps below:

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning) 
import numpy as np
from pyscf import gto, scf, qmmm, fci, cc
from nbed.ham_builder import HamiltonianBuilder, get_coupled_cluster_operator
from nbed.utils import list_to_xyz
from nbed.driver import NbedDriver
from nbed.variational_optimization_QNG_TEST import ADAPT_VQE, VQE_Driver
from symmer import PauliwordOp, QubitTapering
from symmer.utils import exact_gs_energy
from symmer.evolution import PauliwordOp_to_QuantumCircuit

geom = [
    ("O",(0,0,0)),
    ("H",(0.952519,0,0)),
    ("H",(-0.246530058, 0.9200627021, 0))
]
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-10-16 17:28:41</td></tr>
# <tr><td>Running for: </td><td>00:00:56.10        </td></tr>
# <tr><td>Memory:      </td><td>6.5/7.7 GiB        </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 3.0/8 CPUs, 0/2 GPUs (0.0/1.0 accelerator_type:P600)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                 </th><th>status    </th><th>loc                 </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">   ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_CartPole-v1_92ef9_00000</td><td>TERMINATED</td><td>128.40.152.199:12458</td><td style="text-align: right;">     3</td><td style="text-align: right;">         28.8769</td><td style="text-align: right;">12000</td><td style="text-align: right;">    75.7</td><td style="text-align: right;">                 402</td><td style="text-align: right;">                  12</td><td style="text-align: right;">              75.7</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-10-16 17:28:41,236	INFO tune.py:1016 -- Wrote the latest version of all result files and experiment state to '/home/maidaw/ray_results/PPO_2024-10-16_17-27-45' in 0.0190s.
# 2024-10-16 17:28:41,707	INFO tune.py:1048 -- Total run time: 56.61 seconds (56.08 seconds for the tuning loop).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 8
#       6 from nbed.utils import list_to_xyz
#       7 from nbed.driver import NbedDriver
# ----> 8 from nbed.variational_optimization_QNG_TEST import ADAPT_VQE, VQE_Driver
#       9 from symmer import PauliwordOp, QubitTapering
#      10 from symmer.utils import exact_gs_energy
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization_QNG_TEST.py:5
#       3 from qiskit.opflow import CircuitStateFn
#       4 from qiskit import QuantumCircuit
# ----> 5 from ray.rllib.examples.sb2rllib_rllib_example import learning_rate
#       6 from symmer import QuantumState, PauliwordOp
#       7 from nbed.process_handler import process
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/ray/rllib/examples/sb2rllib_rllib_example.py:33
#      31 analysis.default_metric = "episode_reward_mean"
#      32 analysis.default_mode = "max"
# ---> 33 checkpoint_path = analysis.get_best_checkpoint(trial=analysis.get_best_trial())
#      34 print(f"Trained model saved at {checkpoint_path}")
#      36 # load and restore model
#
# AttributeError: 'ResultGrid' object has no attribute 'get_best_checkpoint'

# %% [markdown]
# Having defined the molecule geometry, use ``Nbed`` to perform projection-based embedding:

# %%
embed_mol = NbedDriver(
    geometry=list_to_xyz(geom), 
    n_active_atoms=2,
    basis='sto-3g', 
    xc_functional='cam-b3lyp',
    projector='mu',
    # run_qmmm=True,
    # mm_charges=charges,
    # mm_coords=coords,
    # max_dft_cycles=1000,
)
e_fci = fci.FCI(scf.RHF(embed_mol._build_mol()).run()).run().e_tot
emb_corr = (
    embed_mol.e_env 
    + embed_mol.two_e_cross 
    - embed_mol._mu["correction"] 
    - embed_mol._mu["beta_correction"]
) # embedding correction
e_pbe = embed_mol._run_emb_FCI(embed_mol.embedded_scf).e_tot + emb_corr
print(f'Full-system FCI energy: {e_fci}, Embedded FCI-in-DFT energy: {e_pbe}')
# Out:
# Warning: <pyscf.gto.mole.Mole object at 0x7f75bb3c3b50> must be initialized before calling SCF.
# Initialize <pyscf.gto.mole.Mole object at 0x7f75bb3c3b50> in <pyscf.dft.rks.RKS object at 0x7f75bb3c3be0>
# converged SCF energy = -74.9620396784631
# Full-system FCI energy: -75.01084664816922, Embedded FCI-in-DFT energy: -75.06236600830158

# %% [markdown]
# ``Nbed`` provides the functionality to extract the qubit Hamiltonian for the embedded region, which you may solve using your favourite eigensolver algorithm... note is might take a few second for a ``Ray`` instance to start up, which only happens once.

# %%
ham_builder = HamiltonianBuilder(embed_mol.embedded_scf, constant_e_shift=embed_mol._mu['nuc'])
H = PauliwordOp.from_openfermion(ham_builder.build(taper=False))
hf_state = ham_builder.get_hartree_fock_state()
QT = QubitTapering(H)
H = QT.taper_it(ref_state=hf_state)
hf_state = QT.tapered_ref_state
assert H.n_qubits == hf_state.n_qubits
e0, psi0 = exact_gs_energy(H.to_sparse_matrix)
assert np.isclose(embed_mol._run_emb_FCI(embed_mol.embedded_scf).e_tot, e0, atol=1e-8)
# Out:
# 2024-10-16 15:30:09,873	INFO worker.py:1752 -- Started a local Ray instance.
# (pid=27790) /home/maidaw/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/cotengra/hyperoptimizers/hyper.py:33: UserWarning: Couldn't import `kahypar` - skipping from default hyper optimizer and using basic `labels` method instead.
# (pid=27790)   warnings.warn(

# %% [markdown]
# To run ADAPT-VQE, we need to define our operator pool. For this example, we will take the coupled-cluster singles and doubles (CCSD) excitations, which we build now:

# %%
ccsd,_=embed_mol._run_emb_CCSD(embed_mol.embedded_scf)
CCSD_generator = get_coupled_cluster_operator(ccsd)
CCSD_generator -= CCSD_generator.dagger
CCSD_generator = QT.taper_it(aux_operator=CCSD_generator).sort()
CCSD_generator.sigfig=8
assert(CCSD_generator.n_qubits == H.n_qubits)
print(CCSD_generator)
# Out:
#  0.00000000-0.00717407j IIIIYYYII +
#  0.00000000+0.00717407j IIIIYXXII +
#  0.00000000-0.00717407j IIIIXYXII +
#  0.00000000-0.00000094j ZZZZIZXYZ +
#  0.00000000-0.00000094j ZZZZIZYXZ +
#  0.00000000+0.00000094j IIIIIXZZY +
#  0.00000000+0.00000094j IIIIIYZZX +
# -0.00000000-0.00000094j IZIZZXIZY +
# -0.00000000-0.00000094j IZIZZYIZX +
# -0.00000000-0.00000094j ZIZIZXZIY +
# -0.00000000-0.00000094j ZIZIZYZIX +
#  0.00000000-0.00000094j IIIIIIXYI +
#  0.00000000-0.00000094j IIIIIIYXI
# /home/maidaw/Downloads/QMMMbed-main/nbed/ham_builder.py:629: UserWarning: No Hartree-Fock state provided: assumed singlet configuration
#   warnings.warn('No Hartree-Fock state provided: assumed singlet configuration')

# %% [markdown]
# Now we have all the ingredients required to run an ADAPT-VQE routine, namely a Hamiltonian, a pool of excitation operators, and a reference state (for 15 ADAPT cycles this should take about 1 minute to run in this case, although you can play around with the various parameters in ADAPT_VQE.optimize):

# %%
adapt = ADAPT_VQE(
    observable = H,
    excitation_pool = CCSD_generator,
    ref_state = hf_state
)
adapt.topology_aware = False
adapt_result = adapt.optimize(max_cycles=15,atol=1e-5, lr=0.2)
# Out:
# ---------------------------------------
# ADAPT cycle 1
#
# Largest pool derivative ∂P∂θ =  0.19036
#
# Selected excitation generator(s):
#
# 	YXIIIIIXX
#
#  ---------------------------------------
# step 0 gradient: [4.11708314]
# Optimization step 0 :
# 	 Energy = -62.263596812612505 	 |∆| = 4.117083139641836
# step 1 gradient: [-0.37207758]
# Optimization step 1 :
# 	 Energy = -60.91823680912367 	 |∆| = 0.3720775826285283
# step 2 gradient: [-0.37594115]
# Optimization step 2 :
# 	 Energy = -61.1172979734428 	 |∆| = 0.37594114826229674
# step 3 gradient: [-0.38872216]
# Optimization step 3 :
# 	 Energy = -61.31409311237395 	 |∆| = 0.3887221621012557
# step 4 gradient: [-0.41300468]
# Optimization step 4 :
# 	 Energy = -61.508292899727465 	 |∆| = 0.41300468225841325
# step 5 gradient: [-0.45517569]
# Optimization step 5 :
# 	 Energy = -61.69910303536785 	 |∆| = 0.45517569383701567
# step 6 gradient: [-0.5315858]
# Optimization step 6 :
# 	 Energy = -61.88479201680513 	 |∆| = 0.5315857998180572
# step 7 gradient: [-0.69662487]
# Optimization step 7 :
# 	 Energy = -62.0611100879207 	 |∆| = 0.6966248738093843
# step 8 gradient: [-1.31273101]
# Optimization step 8 :
# 	 Energy = -62.213747373981775 	 |∆| = 1.3127310088024045
# step 9 gradient: [1.51515551]
# Optimization step 9 :
# 	 Energy = -62.22771256492335 	 |∆| = 1.515155507051324
# step 10 gradient: [-1.03637346]
# Optimization step 10:
# 	 Energy = -62.17925898480811 	 |∆| = 1.0363734618191467
# step 11 gradient: [4.7644231]
# Optimization step 11:
# 	 Energy = -62.26523261703979 	 |∆| = 4.764423102938237
# step 12 gradient: [-0.38755214]
# Optimization step 12:
# 	 Energy = -60.549016677121756 	 |∆| = 0.3875521444425504
# step 13 gradient: [-0.37517999]
# Optimization step 13:
# 	 Energy = -60.75242582028886 	 |∆| = 0.37517999054861834
# step 14 gradient: [-0.37215549]
# Optimization step 14:
# 	 Energy = -60.95333494864262 	 |∆| = 0.37215548902176343
# step 15 gradient: [-0.3774972]
# Optimization step 15:
# 	 Energy = -61.152007551367156 	 |∆| = 0.3774972014726812
# step 16 gradient: [-0.3920366]
# Optimization step 16:
# 	 Energy = -61.3483812024892 	 |∆| = 0.39203659544844305
# step 17 gradient: [-0.41883676]
# Optimization step 17:
# 	 Energy = -61.542061129195226 	 |∆| = 0.41883676143695686
# step 18 gradient: [-0.46535954]
# Optimization step 18:
# 	 Energy = -61.73213768960683 	 |∆| = 0.4653595369193375
# step 19 gradient: [-0.55128242]
# Optimization step 19:
# 	 Energy = -61.916610293709915 	 |∆| = 0.5512824238719155
# step 20 gradient: [-0.7471813]
# Optimization step 20:
# 	 Energy = -62.09037753771987 	 |∆| = 0.7471812970959301
# step 21 gradient: [-1.65929998]
# Optimization step 21:
# 	 Energy = -62.23464555818211 	 |∆| = 1.6592999759210336
# step 22 gradient: [0.86132244]
# Optimization step 22:
# 	 Energy = -62.1369949353996 	 |∆| = 0.8613224370842284
# step 23 gradient: [3.29470454]
# Optimization step 23:
# 	 Energy = -62.26037380766988 	 |∆| = 3.294704541420506
# step 24 gradient: [-0.39632473]
# Optimization step 24:
# 	 Energy = -61.3878843543705 	 |∆| = 0.39632473289868914
# step 25 gradient: [-0.42630252]
# Optimization step 25:
# 	 Energy = -61.58093019286916 	 |∆| = 0.42630252098479143
# step 26 gradient: [-0.47853616]
# Optimization step 26:
# 	 Energy = -61.77008693225188 	 |∆| = 0.4785361601690977
# step 27 gradient: [-0.57767338]
# Optimization step 27:
# 	 Energy = -61.95297733482259 	 |∆| = 0.5776733842338653
# step 28 gradient: [-0.82178646]
# Optimization step 28:
# 	 Energy = -62.12321750649438 	 |∆| = 0.8217864626870107
# step 29 gradient: [-2.51722533]
# Optimization step 29:
# 	 Energy = -62.25414561388892 	 |∆| = 2.517225330927449
#
# Energy at ADAPT cycle 1: -62.25415
#
# ---------------------------------------
# ADAPT cycle 2
#
# Largest pool derivative ∂P∂θ =  2.04879
#
# Selected excitation generator(s):
#
# 	YXIIIIIYY
#
#  ---------------------------------------
# step 0 gradient: [ 0.24375586 -0.24375586]
# Optimization step 0 :
# 	 Energy = -61.79188955113376 	 |∆| = 0.34472284468966524
# step 1 gradient: [ 0.29815184 -0.29815184]
# Optimization step 1 :
# 	 Energy = -61.973957899293126 	 |∆| = 0.42165037208500356
# step 2 gradient: [ 0.44038149 -0.44038149]
# Optimization step 2 :
# 	 Energy = -62.142016776524265 	 |∆| = 0.6227934808047662
# step 3 gradient: [ 2.04771637 -2.04771637]
# Optimization step 3 :
# 	 Energy = -62.26239387418022 	 |∆| = 2.895908257104204
# step 4 gradient: [-0.18618719  0.18618719]
# Optimization step 4 :
# 	 Energy = -60.94553129356304 	 |∆| = 0.26330845163720024
# step 5 gradient: [-0.18870121  0.18870121]
# Optimization step 5 :
# 	 Energy = -61.144427181657605 	 |∆| = 0.2668638160572582
# step 6 gradient: [-0.19579774  0.19579774]
# Optimization step 6 :
# 	 Energy = -61.341031057967754 	 |∆| = 0.27689982271557245
# step 7 gradient: [-0.20896435  0.20896435]
# Optimization step 7 :
# 	 Energy = -61.53496823003975 	 |∆| = 0.2955202141449118
# step 8 gradient: [-0.23183888  0.23183888]
# Optimization step 8 :
# 	 Energy = -61.72536086483838 	 |∆| = 0.32786968763353436
# step 9 gradient: [-0.27397821  0.27397821]
# Optimization step 9 :
# 	 Energy = -61.91027586752699 	 |∆| = 0.38746369951781207
# step 10 gradient: [-0.3693109  0.3693109]
# Optimization step 10:
# 	 Energy = -62.084808208659695 	 |∆| = 0.522284489410722
# step 11 gradient: [-0.80078038  0.80078038]
# Optimization step 11:
# 	 Energy = -62.23112014235672 	 |∆| = 1.1324744754023444
# step 12 gradient: [ 0.46645824 -0.46645824]
# Optimization step 12:
# 	 Energy = -62.15632289885863 	 |∆| = 0.6596715706717896
# step 13 gradient: [ 3.37659495 -3.37659495]
# Optimization step 13:
# 	 Energy = -62.26611784293675 	 |∆| = 4.7752263746627674
# step 14 gradient: [-0.40514622  0.40514622]
# Optimization step 14:
# 	 Energy = -59.73229012639062 	 |∆| = 0.5729632783112933
# step 15 gradient: [-0.25929478  0.25929478]
# Optimization step 15:
# 	 Energy = -59.99026197507209 	 |∆| = 0.3666981954199455
# step 16 gradient: [-0.22010346  0.22010346]
# Optimization step 16:
# 	 Energy = -60.20860242096312 	 |∆| = 0.3112733028201419
# step 17 gradient: [-0.20101548  0.20101548]
# Optimization step 17:
# 	 Energy = -60.41845514076523 	 |∆| = 0.2842788248851298
# step 18 gradient: [-0.19102747  0.19102747]
# Optimization step 18:
# 	 Energy = -60.623969062754654 	 |∆| = 0.2701536450216202
# step 19 gradient: [-0.1866679  0.1866679]
# Optimization step 19:
# 	 Energy = -60.82655455904799 	 |∆| = 0.2639882736293058
# step 20 gradient: [-0.18670219  0.18670219]
# Optimization step 20:
# 	 Energy = -61.02676891804998 	 |∆| = 0.2640367692426212
# step 21 gradient: [-0.19098361  0.19098361]
# Optimization step 21:
# 	 Energy = -61.224754219932635 	 |∆| = 0.2700916150343075
# step 22 gradient: [-0.20028784  0.20028784]
# Optimization step 22:
# 	 Energy = -61.42033984772059 	 |∆| = 0.28324978320680627
# step 23 gradient: [-0.21677235  0.21677235]
# Optimization step 23:
# 	 Energy = -61.61298044041314 	 |∆| = 0.3065623932193941
# step 24 gradient: [-0.24571508  0.24571508]
# Optimization step 24:
# 	 Energy = -61.80147335916382 	 |∆| = 0.34749360478041597
# step 25 gradient: [-0.30230735  0.30230735]
# Optimization step 25:
# 	 Energy = -61.98306863974841 	 |∆| = 0.42752715102273386
# step 26 gradient: [-0.45428261  0.45428261]
# Optimization step 26:
# 	 Energy = -62.14997010508299 	 |∆| = 0.6424526267682708
# step 27 gradient: [-2.68604098  2.68604098]
# Optimization step 27:
# 	 Energy = -62.26477710183583 	 |∆| = 3.798635586868427
# step 28 gradient: [ 0.21456768 -0.21456768]
# Optimization step 28:
# 	 Energy = -60.25731785835674 	 |∆| = 0.30344452132494953
# step 29 gradient: [ 0.19809909 -0.19809909]
# Optimization step 29:
# 	 Energy = -60.46596649727749 	 |∆| = 0.28015442409367153
#
# Energy at ADAPT cycle 2: -60.46597
#
# ---------------------------------------
# ADAPT cycle 3
#
# Largest pool derivative ∂P∂θ =  2.63529
#
# Selected excitation generator(s):
#
# 	XYIIIIIXX
#
#  ---------------------------------------
# step 0 gradient: [ 0.12642744 -0.12642744  0.12642744]
# Optimization step 0 :
# 	 Energy = -60.67072653965662 	 |∆| = 0.21897874707762965
# step 1 gradient: [ 0.12423306 -0.12423306  0.12423306]
# Optimization step 1 :
# 	 Energy = -60.8727854758846 	 |∆| = 0.21517797098397565
# step 2 gradient: [ 0.1248952 -0.1248952  0.1248952]
# Optimization step 2 :
# 	 Energy = -61.07253250638429 	 |∆| = 0.21632483310223213
# step 3 gradient: [ 0.12845301 -0.12845301  0.12845301]
# Optimization step 3 :
# 	 Energy = -61.2700376421455 	 |∆| = 0.22248713140770546
# step 4 gradient: [ 0.13559192 -0.13559192  0.13559192]
# Optimization step 4 :
# 	 Energy = -61.46505713009449 	 |∆| = 0.23485209974407512
# step 5 gradient: [ 0.14807815 -0.14807815  0.14807815]
# Optimization step 5 :
# 	 Energy = -61.656932988992374 	 |∆| = 0.2564788817159361
# step 6 gradient: [ 0.17031854 -0.17031854  0.17031854]
# Optimization step 6 :
# 	 Energy = -61.84422639979245 	 |∆| = 0.29500036479086683
# step 7 gradient: [ 0.215925 -0.215925  0.215925]
# Optimization step 7 :
# 	 Energy = -62.02353198084606 	 |∆| = 0.3739930639864106
# step 8 gradient: [ 0.35811716 -0.35811716  0.35811716]
# Optimization step 8 :
# 	 Energy = -62.18435433026149 	 |∆| = 0.6202771153657612
# step 9 gradient: [-1.49731985  1.49731985 -1.49731985]
# Optimization step 9 :
# 	 Energy = -62.26299937677197 	 |∆| = 2.593434057884188
# step 10 gradient: [ 0.12552821 -0.12552821  0.12552821]
# Optimization step 10:
# 	 Energy = -60.72582917053799 	 |∆| = 0.21742123280637238
# step 11 gradient: [ 0.12413918 -0.12413918  0.12413918]
# Optimization step 11:
# 	 Energy = -60.927235010057856 	 |∆| = 0.2150153697027954
# step 12 gradient: [ 0.12555925 -0.12555925  0.12555925]
# Optimization step 12:
# 	 Energy = -61.12637938956297 	 |∆| = 0.21747499399247547
# step 13 gradient: [ 0.12998894 -0.12998894  0.12998894]
# Optimization step 13:
# 	 Energy = -61.32324791641022 	 |∆| = 0.2251474480810305
# step 14 gradient: [ 0.13833833 -0.13833833  0.13833833]
# Optimization step 14:
# 	 Energy = -61.51750177691203 	 |∆| = 0.23960901077185603
# step 15 gradient: [ 0.15285044 -0.15285044  0.15285044]
# Optimization step 15:
# 	 Energy = -61.708324956956474 	 |∆| = 0.2647447259602298
# step 16 gradient: [ 0.17933203 -0.17933203  0.17933203]
# Optimization step 16:
# 	 Energy = -61.8939263536227 	 |∆| = 0.31061218901323223
# step 17 gradient: [ 0.23763729 -0.23763729  0.23763729]
# Optimization step 17:
# 	 Energy = -62.069845747844816 	 |∆| = 0.4115998589698528
# step 18 gradient: [ 0.47320666 -0.47320666  0.47320666]
# Optimization step 18:
# 	 Energy = -62.22057772773278 	 |∆| = 0.8196179849484152
# step 19 gradient: [-0.41261496  0.41261496 -0.41261496]
# Optimization step 19:
# 	 Energy = -62.20539517306722 	 |∆| = 0.7146700673824262
# step 20 gradient: [ 0.64585994 -0.64585994  0.64585994]
# Optimization step 20:
# 	 Energy = -62.24256795254471 	 |∆| = 1.1186622330730271
# step 21 gradient: [-0.22490564  0.22490564 -0.22490564]
# Optimization step 21:
# 	 Energy = -62.04455518089294 	 |∆| = 0.38954798997674317
# step 22 gradient: [-0.40000971  0.40000971 -0.40000971]
# Optimization step 22:
# 	 Energy = -62.2013096873903 	 |∆| = 0.6928371402334068
# step 23 gradient: [ 0.7395833 -0.7395833  0.7395833]
# Optimization step 23:
# 	 Energy = -62.24855475127131 	 |∆| = 1.2809958561625894
# step 24 gradient: [-0.18780697  0.18780697 -0.18780697]
# Optimization step 24:
# 	 Energy = -61.93247924421385 	 |∆| = 0.3252912100804369
# step 25 gradient: [-0.26031527  0.26031527 -0.26031527]
# Optimization step 25:
# 	 Energy = -62.10510358108869 	 |∆| = 0.45087928214293865
# step 26 gradient: [-0.67001045  0.67001045 -0.67001045]
# Optimization step 26:
# 	 Energy = -62.244356012097825 	 |∆| = 1.1604921350276707
# step 27 gradient: [ 0.21341474 -0.21341474  0.21341474]
# Optimization step 27:
# 	 Energy = -62.01709622158434 	 |∆| = 0.369645181146264
# step 28 gradient: [ 0.3475406 -0.3475406  0.3475406]
# Optimization step 28:
# 	 Energy = -62.179029229067915 	 |∆| = 0.6019579719409192
# step 29 gradient: [-2.01251467  2.01251467 -2.01251467]
# Optimization step 29:
# 	 Energy = -62.26509186662599 	 |∆| = 3.4857776603267974
#
# Energy at ADAPT cycle 3: -62.26509
#
# ---------------------------------------
# ADAPT cycle 4
#
# Largest pool derivative ∂P∂θ =  1.88674
#
# Selected excitation generator(s):
#
# 	XXIIIIIXY
#
#  ---------------------------------------
# step 0 gradient: [ 0.13241078 -0.13241078  0.13241078 -0.13241078]
# Optimization step 0 :
# 	 Energy = -59.97060003408865 	 |∆| = 0.26482156670943624
# step 1 gradient: [ 0.11125698 -0.11125698  0.11125698 -0.11125698]
# Optimization step 1 :
# 	 Energy = -60.190306739469285 	 |∆| = 0.22251396643016363
# step 2 gradient: [ 0.10114693 -0.10114693  0.10114693 -0.10114693]
# Optimization step 2 :
# 	 Energy = -60.40076361978773 	 |∆| = 0.20229386674134275
# step 3 gradient: [ 0.09584931 -0.09584931  0.09584931 -0.09584931]
# Optimization step 3 :
# 	 Energy = -60.6066604968712 	 |∆| = 0.19169861907550967
# step 4 gradient: [ 0.09346145 -0.09346145  0.09346145 -0.09346145]
# Optimization step 4 :
# 	 Energy = -60.80954058468187 	 |∆| = 0.18692290357978436
# step 5 gradient: [ 0.09330224 -0.09330224  0.09330224 -0.09330224]
# Optimization step 5 :
# 	 Energy = -61.010015097431676 	 |∆| = 0.18660448312783728
# step 6 gradient: [ 0.09525954 -0.09525954  0.09525954 -0.09525954]
# Optimization step 6 :
# 	 Energy = -61.20825829858373 	 |∆| = 0.1905190816508764
# step 7 gradient: [ 0.09967969 -0.09967969  0.09967969 -0.09967969]
# Optimization step 7 :
# 	 Energy = -61.40412896108829 	 |∆| = 0.19935938762491645
# step 8 gradient: [ 0.10756772 -0.10756772  0.10756772 -0.10756772]
# Optimization step 8 :
# 	 Energy = -61.5971224684888 	 |∆| = 0.21513544909520732
# step 9 gradient: [ 0.12137543 -0.12137543  0.12137543 -0.12137543]
# Optimization step 9 :
# 	 Energy = -61.78611462525896 	 |∆| = 0.24275085915207484
# step 10 gradient: [ 0.14802156 -0.14802156  0.14802156 -0.14802156]
# Optimization step 10:
# 	 Energy = -61.9685559575655 	 |∆| = 0.29604311767233327
# step 11 gradient: [ 0.21685476 -0.21685476  0.21685476 -0.21685476]
# Optimization step 11:
# 	 Energy = -62.137387881466864 	 |∆| = 0.43370951833049887
# step 12 gradient: [ 0.93534952 -0.93534952  0.93534952 -0.93534952]
# Optimization step 12:
# 	 Energy = -62.26078227437223 	 |∆| = 1.8706990407742188
# step 13 gradient: [-0.09448172  0.09448172 -0.09448172  0.09448172]
# Optimization step 13:
# 	 Energy = -61.15252094388826 	 |∆| = 0.18896343027672913
# step 14 gradient: [-0.0981407  0.0981407 -0.0981407  0.0981407]
# Optimization step 14:
# 	 Energy = -61.34909430535318 	 |∆| = 0.19628140538574712
# step 15 gradient: [-0.10488922  0.10488922 -0.10488922  0.10488922]
# Optimization step 15:
# 	 Energy = -61.54297916888025 	 |∆| = 0.209778442187158
# step 16 gradient: [-0.11662247  0.11662247 -0.11662247  0.11662247]
# Optimization step 16:
# 	 Energy = -61.73327214124305 	 |∆| = 0.23324493472579633
# step 17 gradient: [-0.13836547  0.13836547 -0.13836547  0.13836547]
# Optimization step 17:
# 	 Energy = -61.91797516026861 	 |∆| = 0.2767309325418168
# step 18 gradient: [-0.18836947  0.18836947 -0.18836947  0.18836947]
# Optimization step 18:
# 	 Energy = -62.091959592195586 	 |∆| = 0.37673894356783677
# step 19 gradient: [-0.4331948  0.4331948 -0.4331948  0.4331948]
# Optimization step 19:
# 	 Energy = -62.23606483895591 	 |∆| = 0.8663895905608783
# step 20 gradient: [ 0.2021374 -0.2021374  0.2021374 -0.2021374]
# Optimization step 20:
# 	 Energy = -62.11652797046174 	 |∆| = 0.4042748071884219
# step 21 gradient: [ 0.5960365 -0.5960365  0.5960365 -0.5960365]
# Optimization step 21:
# 	 Energy = -62.25096275933052 	 |∆| = 1.1920730089675935
# step 22 gradient: [-0.12988436  0.12988436 -0.12988436  0.12988436]
# Optimization step 22:
# 	 Energy = -61.860913661356555 	 |∆| = 0.25976872351007074
# step 23 gradient: [-0.16693579  0.16693579 -0.16693579  0.16693579]
# Optimization step 23:
# 	 Energy = -62.03920641703613 	 |∆| = 0.3338715755322639
# step 24 gradient: [-0.29149429  0.29149429 -0.29149429  0.29149429]
# Optimization step 24:
# 	 Energy = -62.197108342919734 	 |∆| = 0.5829885897522793
# step 25 gradient: [ 0.64572307 -0.64572307  0.64572307 -0.64572307]
# Optimization step 25:
# 	 Energy = -62.25341526750242 	 |∆| = 1.2914461378887037
# step 26 gradient: [-0.11971642  0.11971642 -0.11971642  0.11971642]
# Optimization step 26:
# 	 Energy = -61.76875256539691 	 |∆| = 0.23943283376834756
# step 27 gradient: [-0.14458463  0.14458463 -0.14458463  0.14458463]
# Optimization step 27:
# 	 Energy = -61.95198672580451 	 |∆| = 0.2891692680591973
# step 28 gradient: [-0.2061407  0.2061407 -0.2061407  0.2061407]
# Optimization step 28:
# 	 Energy = -62.12268435827603 	 |∆| = 0.4122814099099976
# step 29 gradient: [-0.66417167  0.66417167 -0.66417167  0.66417167]
# Optimization step 29:
# 	 Energy = -62.25418798167907 	 |∆| = 1.3283433332411594
#
# Energy at ADAPT cycle 4: -62.25419
#
# ---------------------------------------
# ADAPT cycle 5
#
# Largest pool derivative ∂P∂θ =  2.14264
#
# Selected excitation generator(s):
#
# 	XYIIIIIYY
#
#  ---------------------------------------
# step 0 gradient: [ 0.09330208 -0.09330208  0.09330208 -0.09330208 -0.09330208]
# Optimization step 0 :
# 	 Energy = -61.733179895726956 	 |∆| = 0.20862978426231746
# step 1 gradient: [ 0.11069987 -0.11069987  0.11069987 -0.11069987 -0.11069987]
# Optimization step 1 :
# 	 Energy = -61.91790483312172 	 |∆| = 0.24753243043078105
# step 2 gradient: [ 0.15072177 -0.15072177  0.15072177 -0.15072177 -0.15072177]
# Optimization step 2 :
# 	 Energy = -62.091917900979965 	 |∆| = 0.33702411714273484
# step 3 gradient: [ 0.34706433 -0.34706433  0.34706433 -0.34706433 -0.34706433]
# Optimization step 3 :
# 	 Energy = -62.236061822471854 	 |∆| = 0.7760594413520755
# step 4 gradient: [-0.16145018  0.16145018 -0.16145018  0.16145018  0.16145018]
# Optimization step 4 :
# 	 Energy = -62.115905999607406 	 |∆| = 0.36101358732877675
# step 5 gradient: [-0.4736787  0.4736787 -0.4736787  0.4736787  0.4736787]
# Optimization step 5 :
# 	 Energy = -62.25064581221657 	 |∆| = 1.0591777831601994
# step 6 gradient: [ 0.10472147 -0.10472147  0.10472147 -0.10472147 -0.10472147]
# Optimization step 6 :
# 	 Energy = -61.86841243098057 	 |∆| = 0.2341643359153306
# step 7 gradient: [ 0.13548932 -0.13548932  0.13548932 -0.13548932 -0.13548932]
# Optimization step 7 :
# 	 Energy = -62.0462283571517 	 |∆| = 0.3029633395764507
# step 8 gradient: [ 0.2429671 -0.2429671  0.2429671 -0.2429671 -0.2429671]
# Optimization step 8 :
# 	 Energy = -62.202694481213214 	 |∆| = 0.5432909618901829
# step 9 gradient: [-0.42372587  0.42372587 -0.42372587  0.42372587  0.42372587]
# Optimization step 9 :
# 	 Energy = -62.246441514886406 	 |∆| = 0.9474798520595403
# step 10 gradient: [ 0.11956858 -0.11956858  0.11956858 -0.11956858 -0.11956858]
# Optimization step 10:
# 	 Energy = -61.97496498187405 	 |∆| = 0.2673634617780083
# step 11 gradient: [ 0.17725745 -0.17725745  0.17725745 -0.17725745 -0.17725745]
# Optimization step 11:
# 	 Energy = -62.14304381179526 	 |∆| = 0.39635971810331794
# step 12 gradient: [ 0.9077745 -0.9077745  0.9077745 -0.9077745 -0.9077745]
# Optimization step 12:
# 	 Energy = -62.26282950949161 	 |∆| = 2.02984548575771
# step 13 gradient: [-0.07553643  0.07553643 -0.07553643  0.07553643  0.07553643]
# Optimization step 13:
# 	 Energy = -60.70311716110598 	 |∆| = 0.16890459253001436
# step 14 gradient: [-0.07450562  0.07450562 -0.07450562  0.07450562  0.07450562]
# Optimization step 14:
# 	 Energy = -60.904827797140456 	 |∆| = 0.16659962472409384
# step 15 gradient: [-0.07517035  0.07517035 -0.07517035  0.07517035  0.07517035]
# Optimization step 15:
# 	 Energy = -61.10425687590005 	 |∆| = 0.16808600897393014
# step 16 gradient: [-0.07761103  0.07761103 -0.07761103  0.07761103  0.07761103]
# Optimization step 16:
# 	 Energy = -61.30142619411744 	 |∆| = 0.17354352879055046
# step 17 gradient: [-0.08231665  0.08231665 -0.08231665  0.08231665  0.08231665]
# Optimization step 17:
# 	 Energy = -61.4960385310773 	 |∆| = 0.18406561511684974
# step 18 gradient: [-0.0905095  0.0905095 -0.0905095  0.0905095  0.0905095]
# Optimization step 18:
# 	 Energy = -61.68734774379787 	 |∆| = 0.20238539798356486
# step 19 gradient: [-0.10530292  0.10530292 -0.10530292  0.10530292  0.10530292]
# Optimization step 19:
# 	 Energy = -61.87371984143095 	 |∆| = 0.23546448775765424
# step 20 gradient: [-0.1368926  0.1368926 -0.1368926  0.1368926  0.1368926]
# Optimization step 20:
# 	 Energy = -62.051172361523896 	 |∆| = 0.30610117001437814
# step 21 gradient: [-0.25037517  0.25037517 -0.25037517  0.25037517  0.25037517]
# Optimization step 21:
# 	 Energy = -62.20655346294917 	 |∆| = 0.5598558904813418
# step 22 gradient: [ 0.37332453 -0.37332453  0.37332453 -0.37332453 -0.37332453]
# Optimization step 22:
# 	 Energy = -62.24035256838463 	 |∆| = 0.8347790194285951
# step 23 gradient: [-0.14309293  0.14309293 -0.14309293  0.14309293  0.14309293]
# Optimization step 23:
# 	 Energy = -62.0710838354623 	 |∆| = 0.31996552777197745
# step 24 gradient: [-0.28764523  0.28764523 -0.28764523  0.28764523  0.28764523]
# Optimization step 24:
# 	 Energy = -62.22154938115307 	 |∆| = 0.6431942919680887
# step 25 gradient: [ 0.2403027 -0.2403027  0.2403027 -0.2403027 -0.2403027]
# Optimization step 25:
# 	 Energy = -62.201215434454014 	 |∆| = 0.5373331644919258
# step 26 gradient: [-0.44577583  0.44577583 -0.44577583  0.44577583  0.44577583]
# Optimization step 26:
# 	 Energy = -62.24847344641987 	 |∆| = 0.9967850475832123
# step 27 gradient: [ 0.11226314 -0.11226314  0.11226314 -0.11226314 -0.11226314]
# Optimization step 27:
# 	 Energy = -61.92920551773444 	 |∆| = 0.2510280187468832
# step 28 gradient: [ 0.15502504 -0.15502504  0.15502504 -0.15502504 -0.15502504]
# Optimization step 28:
# 	 Energy = -62.10219883305478 	 |∆| = 0.3466465250329512
# step 29 gradient: [ 0.39007606 -0.39007606  0.39007606 -0.39007606 -0.39007606]
# Optimization step 29:
# 	 Energy = -62.24264298409415 	 |∆| = 0.8722365762330185
#
# Energy at ADAPT cycle 5: -62.24264
#
# ---------------------------------------
# ADAPT cycle 6
#
# Largest pool derivative ∂P∂θ =  1.49195
#
# Selected excitation generator(s):
#
# 	XXIIIIIXY
#
#  ---------------------------------------
# step 0 gradient: [-0.1116268  0.1116268 -0.1116268  0.1116268  0.1116268  0.1116268]
# Optimization step 0 :
# 	 Energy = -62.04053216783307 	 |∆| = 0.27342871152392695
# step 1 gradient: [-0.19605118  0.19605118 -0.19605118  0.19605118  0.19605118  0.19605118]
# Optimization step 1 :
# 	 Energy = -62.1982075156659 	 |∆| = 0.48022535911271863
# step 2 gradient: [ 0.41396958 -0.41396958  0.41396958 -0.41396958 -0.41396958 -0.41396958]
# Optimization step 2 :
# 	 Energy = -62.252107705495725 	 |∆| = 1.0140142433177113
# step 3 gradient: [-0.08302265  0.08302265 -0.08302265  0.08302265  0.08302265  0.08302265]
# Optimization step 3 :
# 	 Energy = -61.81619073625541 	 |∆| = 0.2033631294807771
# step 4 gradient: [-0.10318716  0.10318716 -0.10318716  0.10318716  0.10318716  0.10318716]
# Optimization step 4 :
# 	 Energy = -61.99715536861652 	 |∆| = 0.2527558810413302
# step 5 gradient: [-0.16011842  0.16011842 -0.16011842  0.16011842  0.16011842  0.16011842]
# Optimization step 5 :
# 	 Energy = -62.16228122719527 	 |∆| = 0.3922084345589599
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 7
#       1 adapt = ADAPT_VQE(
#       2     observable = H,
#       3     excitation_pool = CCSD_generator,
#       4     ref_state = hf_state
#       5 )
#       6 adapt.topology_aware = False
# ----> 7 adapt_result = adapt.optimize(max_cycles=15,atol=1e-5)
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:845, in ADAPT_VQE.optimize(self, max_cycles, gtol, atol, target, target_error)
#     841 self.prepare_for_evolution(self.adapt_operator)
#     842 # opt_out, vqe_hist = self.run(
#     843 #     x0=np.append(self.opt_parameters, [0]*n_new_terms), method='BFGS'
#     844 # )
# --> 845 opt_out, vqe_hist = self.run_with_qng(
#     846     x0=np.append(self.opt_parameters, [0] * n_new_terms), max_steps=30, learning_rate=0.2
#     847 )
#     849 # opt_out, vqe_hist = self.run_with_spsa_qng(
#     850 #     x0=np.append(self.opt_parameters, [0] * n_new_terms), max_steps=10, learning_rate=0.2
#     851 # )
#     854 interim_data[adapt_cycle] = {
#     855     'output':opt_out, 'history':vqe_hist, 'gmax':gmax,
#     856     'excitation': [symplectic_to_string(t.symp_matrix[0]) for t in new_excitation_list]
#     857 }
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:597, in VQE_Driver.run_with_qng(self, x0, max_steps, learning_rate, clip_value)
#     586 vqe_history['energy'][counter] = energy
#     588 # # 如果能量上升则提前停止
#     589 # if energy > prev_energy:
#     590 #     print(f"由于能量上升，在第 {step} 步提前停止。")
#    (...)
#     595
#     596 # 计算梯度
# --> 597 grad = self.natural_gradient(params)
#     598 print(f"step {step} gradient: {grad}")
#     599 # # 如果设置了裁剪值，执行梯度裁剪
#     600 # grad_norm = np.linalg.norm(grad)
#     601 # if clip_value is not None and grad_norm > clip_value:
#     602 #     grad = grad * (clip_value / grad_norm)
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:302, in VQE_Driver.natural_gradient(self, x)
#     301 def natural_gradient(self, x: np.array) -> np.array:
# --> 302     fisher_information_matrix = self.compute_fisher_information(x)
#     304     # 正则化
#     305     regularization_strength = 1e-2
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:263, in VQE_Driver.compute_fisher_information(self, x, delta)
#     261 partials = np.zeros(num_parameters)
#     262 for i in range(num_parameters):
# --> 263     partials[i] = self.partial_derivative(x, i)
#     265 # Compute the Fisher information matrix (only upper triangular, then mirror)
#     266 for i in range(num_parameters):
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:223, in VQE_Driver.partial_derivative(self, x, param_index)
#     221 x_upper = x.copy(); x_upper[param_index]+=np.pi/4
#     222 x_lower = x.copy(); x_lower[param_index]-=np.pi/4
# --> 223 return self.f(x_upper) - self.f(x_lower)
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:206, in VQE_Driver.f(self, x)
#     204     state = self.get_state(self.excitation_generators, x)
#     205 else:
# --> 206     state = self.get_state(self.circuit, x)
#     207 return self._f(self.observable, state)
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:162, in VQE_Driver.get_state(self, evolution_obj, x)
#     160     return state.to_spmatrix().reshape([-1,1])
#     161 elif self.expectation_eval.find('symbolic') != -1:
# --> 162     return QuantumState.from_array(state.to_matrix().reshape([-1,1]))
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/opflow/state_fns/circuit_state_fn.py:264, in CircuitStateFn.to_matrix(self, massive)
#     262 qc = self.to_circuit(meas=False)
#     263 statevector_backend = BasicAer.get_backend("statevector_simulator")
# --> 264 transpiled = transpile(qc, statevector_backend, optimization_level=0)
#     265 statevector = statevector_backend.run(transpiled).result().get_statevector()
#     266 from ..operator_globals import EVAL_SIG_DIGITS
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/compiler/transpiler.py:419, in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target, hls_config, init_method, optimization_method, ignore_backend_supplied_default_methods)
#     391         instruction_durations = _parse_instruction_durations(
#     392             backend, instruction_durations, dt, circuits[0]
#     393         )
#     395 pm = generate_preset_pass_manager(
#     396     optimization_level,
#     397     backend=backend,
#    (...)
#     417     _skip_target=_skip_target,
#     418 )
# --> 419 out_circuits = pm.run(circuits, callback=callback)
#     420 for name, circ in zip(output_name, out_circuits):
#     421     circ.name = name
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/transpiler/passmanager.py:537, in StagedPassManager.run(self, circuits, output_name, callback)
#     530 def run(
#     531     self,
#     532     circuits: _CircuitsT,
#     533     output_name: str | None = None,
#     534     callback: Callable | None = None,
#     535 ) -> _CircuitsT:
#     536     self._update_passmanager()
# --> 537     return super().run(circuits, output_name, callback)
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/transpiler/passmanager.py:233, in PassManager.run(self, circuits, output_name, callback)
#     231     return self._run_single_circuit(circuits, output_name, callback)
#     232 if len(circuits) == 1:
# --> 233     return [self._run_single_circuit(circuits[0], output_name, callback)]
#     234 return self._run_several_circuits(circuits, output_name, callback)
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/transpiler/passmanager.py:292, in PassManager._run_single_circuit(self, circuit, output_name, callback)
#     280 """Run all the passes on a ``circuit``.
#     281
#     282 Args:
#    (...)
#     289     The transformed circuit.
#     290 """
#     291 running_passmanager = self._create_running_passmanager()
# --> 292 result = running_passmanager.run(circuit, output_name=output_name, callback=callback)
#     293 self.property_set = running_passmanager.property_set
#     294 return result
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py:125, in RunningPassManager.run(***failed resolving arguments***)
#     123 for passset in self.working_list:
#     124     for pass_ in passset:
# --> 125         dag = self._do_pass(pass_, dag, passset.options)
#     127 circuit = dag_to_circuit(dag, copy_operations=False)
#     128 if output_name:
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py:173, in RunningPassManager._do_pass(self, pass_, dag, options)
#     171 # Run the pass itself, if not already run
#     172 if pass_ not in self.valid_passes:
# --> 173     dag = self._run_this_pass(pass_, dag)
#     175     # update the valid_passes property
#     176     self._update_valid_passes(pass_)
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/transpiler/runningpassmanager.py:202, in RunningPassManager._run_this_pass(self, pass_, dag)
#     199 if pass_.is_transformation_pass:
#     200     # Measure time if we have a callback or logging set
#     201     start_time = time()
# --> 202     new_dag = pass_.run(dag)
#     203     end_time = time()
#     204     run_time = end_time - start_time
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/transpiler/passes/basis/basis_translator.py:160, in BasisTranslator.run(self, dag)
#     158 # Search for a path from source to target basis.
#     159 search_start_time = time.time()
# --> 160 basis_transforms = _basis_search(self._equiv_lib, source_basis, target_basis)
#     162 qarg_local_basis_transforms = {}
#     163 for qarg, local_source_basis in qargs_local_source_basis.items():
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/transpiler/passes/basis/basis_translator.py:523, in _basis_search(equiv_lib, source_basis, target_basis)
#     521 rtn = None
#     522 try:
# --> 523     rustworkx.digraph_dijkstra_search(graph, [dummy], vis.edge_cost, vis)
#     524 except StopIfBasisRewritable:
#     525     rtn = vis.basis_transforms
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/transpiler/passes/basis/basis_translator.py:417, in BasisSearchVisitor.discover_vertex(self, v, score)
#     415 rule = self._predecessors.get(gate, None)
#     416 if rule is not None:
# --> 417     logger.debug(
#     418         "Gate %s generated using rule \n%s\n with total cost of %s.",
#     419         gate.name,
#     420         rule.circuit,
#     421         score,
#     422     )
#     423     self._basis_transforms.append((gate.name, gate.num_qubits, rule.params, rule.circuit))
#     424 # we can stop the search if we have found all gates in the original ciruit.
#
# File /usr/lib/python3.8/logging/__init__.py:1422, in Logger.debug(self, msg, *args, **kwargs)
#    1413 """
#    1414 Log 'msg % args' with severity 'DEBUG'.
#    1415
#    (...)
#    1419 logger.debug("Houston, we have a %s", "thorny problem", exc_info=1)
#    1420 """
#    1421 if self.isEnabledFor(DEBUG):
# -> 1422     self._log(DEBUG, msg, args, **kwargs)
#
# File /usr/lib/python3.8/logging/__init__.py:1577, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1574         exc_info = sys.exc_info()
#    1575 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1576                          exc_info, func, extra, sinfo)
# -> 1577 self.handle(record)
#
# File /usr/lib/python3.8/logging/__init__.py:1587, in Logger.handle(self, record)
#    1580 """
#    1581 Call the handlers for the specified record.
#    1582
#    1583 This method is used for unpickled records received from a socket, as
#    1584 well as those created locally. Logger-level filtering is applied.
#    1585 """
#    1586 if (not self.disabled) and self.filter(record):
# -> 1587     self.callHandlers(record)
#
# File /usr/lib/python3.8/logging/__init__.py:1649, in Logger.callHandlers(self, record)
#    1647     found = found + 1
#    1648     if record.levelno >= hdlr.level:
# -> 1649         hdlr.handle(record)
#    1650 if not c.propagate:
#    1651     c = None    #break out
#
# File /usr/lib/python3.8/logging/__init__.py:950, in Handler.handle(self, record)
#     948 self.acquire()
#     949 try:
# --> 950     self.emit(record)
#     951 finally:
#     952     self.release()
#
# File /usr/lib/python3.8/logging/__init__.py:1183, in FileHandler.emit(self, record)
#    1181 if self.stream is None:
#    1182     self.stream = self._open()
# -> 1183 StreamHandler.emit(self, record)
#
# File /usr/lib/python3.8/logging/__init__.py:1081, in StreamHandler.emit(self, record)
#    1070 """
#    1071 Emit a record.
#    1072
#    (...)
#    1078 output to the stream.
#    1079 """
#    1080 try:
# -> 1081     msg = self.format(record)
#    1082     stream = self.stream
#    1083     # issue 35046: merged two stream.writes into one.
#
# File /usr/lib/python3.8/logging/__init__.py:925, in Handler.format(self, record)
#     923 else:
#     924     fmt = _defaultFormatter
# --> 925 return fmt.format(record)
#
# File /usr/lib/python3.8/logging/__init__.py:664, in Formatter.format(self, record)
#     651 def format(self, record):
#     652     """
#     653     Format the specified record as text.
#     654
#    (...)
#     662     it is formatted using formatException() and appended to the message.
#     663     """
# --> 664     record.message = record.getMessage()
#     665     if self.usesTime():
#     666         record.asctime = self.formatTime(record, self.datefmt)
#
# File /usr/lib/python3.8/logging/__init__.py:369, in LogRecord.getMessage(self)
#     367 msg = str(self.msg)
#     368 if self.args:
# --> 369     msg = msg % self.args
#     370 return msg
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/circuit/quantumcircuit.py:496, in QuantumCircuit.__str__(self)
#     495 def __str__(self) -> str:
# --> 496     return str(self.draw(output="text"))
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/visualization/circuit/text.py:656, in TextDrawing.__str__(self)
#     655 def __str__(self):
# --> 656     return self.single_string()
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/visualization/circuit/text.py:677, in TextDrawing.single_string(self)
#     672 """Creates a long string with the ascii art.
#     673 Returns:
#     674     str: The lines joined by a newline (``\\n``)
#     675 """
#     676 try:
# --> 677     return "\n".join(self.lines()).encode(self.encoding).decode(self.encoding)
#     678 except (UnicodeEncodeError, UnicodeDecodeError):
#     679     warn(
#     680         "The encoding %s has a limited charset. Consider a different encoding in your "
#     681         "environment. UTF-8 is being used instead" % self.encoding,
#     682         RuntimeWarning,
#     683     )
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/visualization/circuit/text.py:735, in TextDrawing.lines(self, line_length)
#     732     continue
#     734 # chop the layer to the line_length (pager)
# --> 735 layer_length = layers[layerno][0].length
#     737 if layer_length < rest_of_the_line:
#     738     layer_groups[-1].append(layer)
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/visualization/circuit/text.py:111, in DrawElement.length(self)
#     108 @property
#     109 def length(self):
#     110     """Returns the length of the element, including the box around."""
# --> 111     return max(len(self.top), len(self.mid), len(self.bot))
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/qiskit/visualization/circuit/text.py:78, in DrawElement.top(self)
#      76 if self.left_fill:
#      77     ret = ret.rjust(self.left_fill, self.top_pad)
# ---> 78 ret = ret.center(self.layer_width, self.top_bck)
#      79 return ret
#
# KeyboardInterrupt:

# %% [markdown]
# **Note:** For comparison, we choose different optimization methods for VQE when the circuit is fixed and see their performance.

# %%
import matplotlib.pyplot as plt

x_values = adapt_result['result']['x']
# Create a new array of zeros with the same shape as x_values
x_zeros = [0.0] * len(x_values)
x_random = np.random.rand(len(x_values))

# Define: 'BFGS', 'CG', 'SLSQP', 'SPSA_NaturalGradient'
methods = ['BFGS', 'CG', 'SLSQP', 'NaturalGradient', 'SPSA_NaturalGradient']
result_histories = {}

# Factor to scale the iterations for scipy methods
scipy_step_scaling = 1

for method in methods:
    if method == 'NaturalGradient':
        print(f'We are using "{method}" now.')
        result, history = adapt.run_with_qng(x0=x_random,  max_steps=30)  # Max steps set to 50
    elif method == 'SPSA_NaturalGradient':
        print(f'We are using "{method}" now.')
        result, history = adapt.run_with_spsa_qng(x0=x_random, max_steps=30, learning_rate=0.3)  # Max steps set to 50
    else:
        print(f'We are using "{method}" now.')
        # Use a general gradient descent method for other optimizers
        result, history = adapt.run(x0=x_random, method=method, options={'maxiter': 10})  # 'maxiter' controls the number of iterations

    
    # Save result history
    result_histories[method] = history


plt.figure(figsize=(10, 6))

for method in methods:
    if method == 'SPSA_NaturalGradient' or method == 'NaturalGradient':
        # Plot SPSA and Natural Gradient results with regular iteration steps
        energy_history = [result_histories[method]['energy'][i] for i in result_histories[method]['energy']]
        plt.plot(energy_history, label=method)
    else:
        # Multiply the x-axis (iterations) by the step scaling factor for scipy methods
        energy_history = [result_histories[method]['energy'][i] for i in result_histories[method]['energy']]
        plt.plot([scipy_step_scaling * i for i in range(len(energy_history))], energy_history, label=method)

plt.xlabel('Iteration')
plt.ylabel('Energy')
plt.title('Energy Optimization with Different Methods')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# We are using "BFGS" now.
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -60.9822933452865
# 	    |∆| = 3.0064422379953224
# Optimization step 1 :
# 	 Energy = -59.734336612483816
# 	    |∆| = 6.155097692010209
# Optimization step 2 :
# 	 Energy = -61.444402857575504
# 	    |∆| = 5.133694288254765
# Optimization step 3 :
# 	 Energy = -62.06785236002301
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f6f341c6e20>>
# Traceback (most recent call last):
# Exception ignored in:   File "/home/maidaw/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
# <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f6f341c6e20>>
# Exception ignored in: def _clean_thread_parent_frames(Traceback (most recent call last):
#
#   File "/home/maidaw/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f6f341c6e20>><bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f6f341c6e20>>
# Exception ignored in: KeyboardInterrupt
# Traceback (most recent call last):
# :   File "/home/maidaw/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#
# <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f6f341c6e20>>Traceback (most recent call last):
#   File "/home/maidaw/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#
# Traceback (most recent call last):
#   File "/home/maidaw/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f6f341c6e20>>
# Traceback (most recent call last):
#   File "/home/maidaw/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(                def _clean_thread_parent_frames(Exception ignored in:
# def _clean_thread_parent_frames(def _clean_thread_parent_frames(<bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f6f341c6e20>>def _clean_thread_parent_frames(
#
#
# KeyboardInterruptTraceback (most recent call last):
# KeyboardInterrupt  File "/home/maidaw/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#
# : KeyboardInterrupt
# KeyboardInterrupt: : KeyboardInterrupt
# : :
#
# Exception ignored in:
#     def _clean_thread_parent_frames(
# <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7f6f341c6e20>>
#
# KeyboardInterruptTraceback (most recent call last):
# :
#   File "/home/maidaw/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 25
#      23     print(f'We are using "{method}" now.')
#      24     # Use a general gradient descent method for other optimizers
# ---> 25     result, history = adapt.run(x0=x_random, method=method, options={'maxiter': 10})  # 'maxiter' controls the number of iterations
#      28 # Save result history
#      29 result_histories[method] = history
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:422, in VQE_Driver.run(self, x0, **kwargs)
#     420 if self.verbose:
#     421     print('VQE simulation commencing...\n')
# --> 422 opt_out = minimize(
#     423     fun=fun, jac=jac, x0=x0, **kwargs
#     424 )
#     425 return serialize_opt_data(opt_out), vqe_history
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_minimize.py:691, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     689     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     690 elif meth == 'bfgs':
# --> 691     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     692 elif meth == 'newton-cg':
#     693     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     694                              **options)
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py:1388, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1385 pk = -np.dot(Hk, gfk)
#    1386 try:
#    1387     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1388              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1389                                   old_fval, old_old_fval, amin=1e-100, amax=1e100)
#    1390 except _LineSearchError:
#    1391     # Line search failed to find a better solution.
#    1392     warnflag = 2
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_optimize.py:1160, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1146 """
#    1147 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1148 suitable step length is not found, and raise an exception if a
#    (...)
#    1155
#    1156 """
#    1158 extra_condition = kwargs.pop('extra_condition', None)
# -> 1160 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1161                          old_fval, old_old_fval,
#    1162                          **kwargs)
#    1164 if ret[0] is not None and extra_condition is not None:
#    1165     xp1 = xk + ret[0] * pk
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_linesearch.py:84, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      80     return np.dot(gval[0], pk)
#      82 derphi0 = np.dot(gfk, pk)
# ---> 84 stp, fval, old_fval = scalar_search_wolfe1(
#      85         phi, derphi, old_fval, old_old_fval, derphi0,
#      86         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      88 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_linesearch.py:161, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     159     alpha1 = stp
#     160     phi1 = phi(stp)
# --> 161     derphi1 = derphi(stp)
#     162 else:
#     163     break
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_linesearch.py:78, in line_search_wolfe1.<locals>.derphi(s)
#      77 def derphi(s):
# ---> 78     gval[0] = fprime(xk + s*pk, *args)
#      79     gc[0] += 1
#      80     return np.dot(gval[0], pk)
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:273, in ScalarFunction.grad(self, x)
#     271 if not np.array_equal(x, self.x):
#     272     self._update_x_impl(x)
# --> 273 self._update_grad()
#     274 return self.g
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:167, in ScalarFunction.__init__.<locals>.update_grad()
#     166 def update_grad():
# --> 167     self.g = grad_wrapped(self.x)
#
# File ~/Downloads/QMMMbed-main/venv/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:164, in ScalarFunction.__init__.<locals>.grad_wrapped(x)
#     162 def grad_wrapped(x):
#     163     self.ngev += 1
# --> 164     return np.atleast_1d(grad(np.copy(x), *args))
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:414, in VQE_Driver.run.<locals>.jac(x)
#     412 def jac(x):
#     413     counter = get_counter(increment=False)
# --> 414     grad    = self.gradient(x)
#     415     vqe_history['gradient'][counter] = tuple(grad)
#     416     if self.verbose:
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:239, in VQE_Driver.gradient(self, x)
#     236     @process.parallelize
#     237     def f(index, param):
#     238         return self.partial_derivative(param,index)
# --> 239     grad_vec = f(range(self.circuit.num_parameters), x)
#     241 else:
#     242     grad_vec = [self.partial_derivative(x, i) for i in range(self.circuit.num_parameters)]
#
# File ~/Downloads/QMMMbed-main/nbed/process_handler.py:103, in ProcessHandler.parallelize.<locals>.wrapper(iter, shared)
#     100 _func = lambda iter,shared: [func(i, shared) for i in iter]
#     102 if self.method   == 'mp':
# --> 103     return self._process_mp(_func, iter, shared)
#     104 elif self.method == 'ray':
#     105     return self._process_ray(_func, iter, shared)
#
# File ~/Downloads/QMMMbed-main/nbed/process_handler.py:80, in ProcessHandler._process_mp(self, func, iter, shared)
#      78 data = []
#      79 for _ in range(self.n_chunks):
# ---> 80     data.append(queue.get())
#      81 # complete the processes
#      82 for proc in procs:
#
# File /usr/lib/python3.8/multiprocessing/queues.py:97, in Queue.get(self, block, timeout)
#      95 if block and timeout is None:
#      96     with self._rlock:
# ---> 97         res = self._recv_bytes()
#      98     self._sem.release()
#      99 else:
#
# File /usr/lib/python3.8/multiprocessing/connection.py:216, in _ConnectionBase.recv_bytes(self, maxlength)
#     214 if maxlength is not None and maxlength < 0:
#     215     raise ValueError("negative maxlength")
# --> 216 buf = self._recv_bytes(maxlength)
#     217 if buf is None:
#     218     self._bad_message_length()
#
# File /usr/lib/python3.8/multiprocessing/connection.py:414, in Connection._recv_bytes(self, maxsize)
#     413 def _recv_bytes(self, maxsize=None):
# --> 414     buf = self._recv(4)
#     415     size, = struct.unpack("!i", buf.getvalue())
#     416     if size == -1:
#
# File /usr/lib/python3.8/multiprocessing/connection.py:379, in Connection._recv(self, size, read)
#     377 remaining = size
#     378 while remaining > 0:
# --> 379     chunk = read(handle, remaining)
#     380     n = len(chunk)
#     381     if n == 0:
#
# KeyboardInterrupt:

# %% [markdown]
# and we may plot the convergence:

# %%
from matplotlib import pyplot as plt

fig, axis = plt.subplots()
fig.tight_layout()
Y_adapt = [embed_mol.embedded_scf.e_tot]
X_adapt = [0]

# niter = len(out['interim_data']['history'])
niter=len(adapt_result['interim_data'].keys())-1
offset=0
prev = 0
colors=[]
for i in range(1,niter+1):
    c = plt.cm.plasma_r(i/niter)
    colors.append(c)
    # i = str(i)
    # params   = out['interim_data'][i]['history']['params']
    energy   = adapt_result['interim_data'][i]['history']['energy']
    gradient = adapt_result['interim_data'][i]['history']['gradient']
    X, Y = zip(*energy.items())
    Y = np.array(Y)
    X = offset+np.array([int(x) for x in X])
    axis.plot(X, abs(Y+emb_corr-e_pbe), lw=1.2, zorder=10, color=c)
    grad_norm = np.linalg.norm(list(gradient.values()), axis=1)
    offset+=(len(X)-1)
    X_adapt.append(offset)
    Y_adapt.append(adapt_result['interim_data'][i]['output']['fun'])

axis.plot(
    X_adapt, abs(np.array(Y_adapt)+emb_corr-e_pbe), ms=5,
    ls=':', color='black', marker='d', label='ADAPT energy after\neach VQE routine', zorder=10, lw=1
)

axis.set_ylabel('Error from target embedding energy [Ha]')
axis.set_xlabel('Optimization step')
axis.set_yscale('log')
axis.legend()
axis.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 fig, axis = plt.subplots()
#       4 fig.tight_layout()
# ----> 5 Y_adapt = [embed_mol.embedded_scf.e_tot]
#       6 X_adapt = [0]
#       8 # niter = len(out['interim_data']['history'])
#
# NameError: name 'embed_mol' is not defined

# %% [markdown]
# You can see that, at each step, ADAPT selects one of the CCSD excitations, appends it to a growing circuit, and reoptimizes the variational parameters through VQE. The final set of excitation generators is:

# %%
scipy_step_scaling = 5
# 画出能量随迭代次数变化的图像
plt.figure(figsize=(10, 6))

for method in methods:
    if method == 'SPSA_NaturalGradient' or method == 'NaturalGradient':
        # Plot SPSA and Natural Gradient results with regular iteration steps
        energy_history = [result_histories[method]['energy'][i] for i in result_histories[method]['energy']]
        plt.plot(energy_history, label=method)
    else:
        # Multiply the x-axis (iterations) by the step scaling factor for scipy methods
        energy_history = [result_histories[method]['energy'][i] for i in result_histories[method]['energy']]
        plt.plot([scipy_step_scaling * i for i in range(len(energy_history))], energy_history, label=method)

plt.xlabel('Iteration')
plt.ylabel('Energy')
plt.title('Energy Optimization with Different Methods')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(adapt_result['adapt_operator'])
#
# NameError: name 'adapt_result' is not defined

# %% [markdown]
# With corresponding quantum circuit:

# %%
qc = PauliwordOp_to_QuantumCircuit(
    PauliwordOp.from_list(adapt_result['adapt_operator']), 
    bind_params=False,
    include_barriers=False
)
qc.draw()
# Out:
#       ┌───┐                                               ┌───┐ ┌─────┐┌───┐»
# q_0: ─┤ H ├───■───────────────────────────────────────■───┤ H ├─┤ Sdg ├┤ H ├»
#       ├───┤ ┌─┴─┐                                   ┌─┴─┐ ├───┤ ├─────┤├───┤»
# q_1: ─┤ H ├─┤ X ├──■─────────────────────────────■──┤ X ├─┤ H ├─┤ Sdg ├┤ H ├»
#      ┌┴───┴┐├───┤  │                             │  └───┘ └───┘ └─────┘└───┘»
# q_2: ┤ Sdg ├┤ H ├──┼────■────────────────────────┼──────────────────────────»
#      └┬───┬┘└───┘  │  ┌─┴─┐                      │                          »
# q_3: ─┤ H ├────────┼──┤ X ├──────────────────────┼───────────────────────■──»
#      ┌┴───┴┐┌───┐  │  └───┘                      │                       │  »
# q_4: ┤ Sdg ├┤ H ├──┼─────────────────────────────┼───────────────────────┼──»
#      ├─────┤├───┤  │                             │                       │  »
# q_5: ┤ Sdg ├┤ H ├──┼─────────────────────────────┼───────────────────────┼──»
#      └┬───┬┘└───┘  │                             │                       │  »
# q_6: ─┤ H ├────────┼─────────────────────────────┼───────────────────────┼──»
#       ├───┤      ┌─┴─┐                         ┌─┴─┐┌───┐┌─────┐ ┌───┐ ┌─┴─┐»
# q_7: ─┤ H ├──────┤ X ├──■───────────────────■──┤ X ├┤ H ├┤ Sdg ├─┤ H ├─┤ X ├»
#      ┌┴───┴┐┌───┐└───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤├───┤├─────┤ ├───┤ └───┘»
# q_8: ┤ Sdg ├┤ H ├─────┤ X ├┤ Rz(-2*P[0]) ├┤ X ├┤ H ├┤ S ├┤ Sdg ├─┤ H ├──────»
#      └─────┘└───┘     └───┘└─────────────┘└───┘└───┘└───┘└─────┘ └───┘      »
# «                                                                   ┌───┐»
# «q_0: ──■───────────────────────────────────────────────────────■───┤ H ├»
# «     ┌─┴─┐                                                   ┌─┴─┐ ├───┤»
# «q_1: ┤ X ├───────■───────────────────────────────────────■───┤ X ├─┤ H ├»
# «     └───┘       │                                       │   ├───┤ ├───┤»
# «q_2: ────────────┼──────────────────────────────────■────┼───┤ H ├─┤ S ├»
# «                 │                                ┌─┴─┐  │   ├───┤ ├───┤»
# «q_3: ────────────┼─────────────────────────────■──┤ X ├──┼───┤ H ├─┤ H ├»
# «                 │                             │  └───┘  │   └───┘ └───┘»
# «q_4: ────────────┼─────────────────────────────┼─────────┼──────────────»
# «               ┌─┴─┐                           │       ┌─┴─┐ ┌───┐ ┌───┐»
# «q_5: ──────────┤ X ├───────■───────────────────┼────■──┤ X ├─┤ H ├─┤ S ├»
# «               └───┘     ┌─┴─┐┌─────────────┐  │  ┌─┴─┐├───┤┌┴───┴┐├───┤»
# «q_6: ────────────────────┤ X ├┤ Rz(-2*P[1]) ├──┼──┤ X ├┤ H ├┤ Sdg ├┤ H ├»
# «                         └───┘└─────────────┘┌─┴─┐├───┤├───┤└┬───┬┘└───┘»
# «q_7: ──■───────────────────■─────────────────┤ X ├┤ H ├┤ S ├─┤ H ├──────»
# «     ┌─┴─┐┌─────────────┐┌─┴─┐     ┌───┐     ├───┤├───┤└───┘ └───┘      »
# «q_8: ┤ X ├┤ Rz(-2*P[2]) ├┤ X ├─────┤ H ├─────┤ S ├┤ H ├─────────────────»
# «     └───┘└─────────────┘└───┘     └───┘     └───┘└───┘                 »
# «      ┌───┐ ┌─────┐┌───┐                                                      »
# «q_0: ─┤ S ├─┤ Sdg ├┤ H ├──■───────────────────────────────────────────────────»
# «      ├───┤ └─────┘└───┘┌─┴─┐                                                 »
# «q_1: ─┤ S ├─────────────┤ X ├─────────────────────────────────────────────────»
# «     ┌┴───┴┐ ┌───┐      └───┘                                    ┌───┐  ┌───┐ »
# «q_2: ┤ Sdg ├─┤ H ├───■───────────────────────────────────────■───┤ H ├──┤ S ├─»
# «     └─────┘ └───┘ ┌─┴─┐                                   ┌─┴─┐ ├───┤ ┌┴───┴┐»
# «q_3: ──────────────┤ X ├──■─────────────────────────────■──┤ X ├─┤ H ├─┤ Sdg ├»
# «                   └───┘  │                             │  └───┘ └───┘ └─────┘»
# «q_4: ─────────────────────┼─────────────────────────────┼─────────────────────»
# «     ┌─────┐ ┌───┐      ┌─┴─┐                         ┌─┴─┐┌───┐ ┌───┐ ┌─────┐»
# «q_5: ┤ Sdg ├─┤ H ├──────┤ X ├──■───────────────────■──┤ X ├┤ H ├─┤ S ├─┤ Sdg ├»
# «     └─────┘ └───┘      └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤├───┤┌┴───┴┐└┬───┬┘»
# «q_6: ────────────────────────┤ X ├┤ Rz(-2*P[3]) ├┤ X ├┤ H ├┤ S ├┤ Sdg ├─┤ H ├─»
# «                             └───┘└─────────────┘└───┘└───┘└───┘└─────┘ └───┘ »
# «q_7: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_8: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «                                                                            »
# «q_0: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_1: ───────────────────────────────────────────────────────────────────────»
# «     ┌─────┐┌───┐                                               ┌───┐ ┌───┐ »
# «q_2: ┤ Sdg ├┤ H ├──■────────────────────────────────────────■───┤ H ├─┤ S ├─»
# «     └┬───┬┘└───┘┌─┴─┐                                    ┌─┴─┐ ├───┤ ├───┤ »
# «q_3: ─┤ H ├──────┤ X ├──■─────────────────────────────■───┤ X ├─┤ H ├─┤ S ├─»
# «      └───┘      └───┘  │                             │   └───┘ └───┘ └───┘ »
# «q_4: ───────────────────┼─────────────────────────────┼─────────────────────»
# «      ┌───┐             │                             │                     »
# «q_5: ─┤ H ├─────────────┼─────────────────────────────┼─────────────────────»
# «      └───┘           ┌─┴─┐                         ┌─┴─┐ ┌───┐ ┌───┐┌─────┐»
# «q_6: ─────────────────┤ X ├──■───────────────────■──┤ X ├─┤ H ├─┤ S ├┤ Sdg ├»
# «                      └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤┌┴───┴┐├───┤└─────┘»
# «q_7: ──────────────────────┤ X ├┤ Rz(-2*P[4]) ├┤ X ├┤ H ├┤ Sdg ├┤ H ├───────»
# «                           └───┘└─────────────┘└───┘└───┘└─────┘└───┘       »
# «q_8: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                   ┌───┐┌───┐»
# «q_0: ──────────────────────────────────────────────────────────■───┤ H ├┤ S ├»
# «                                                             ┌─┴─┐ └───┘└───┘»
# «q_1: ──■─────────────────────────────────────────────────■───┤ X ├───────────»
# «     ┌─┴─┐                                             ┌─┴─┐ └───┘           »
# «q_2: ┤ X ├──■───────────────────────────────────────■──┤ X ├─────────────────»
# «     ├───┤┌─┴─┐                                   ┌─┴─┐├───┤ ┌───┐           »
# «q_3: ┤ H ├┤ X ├──■─────────────────────────────■──┤ X ├┤ H ├─┤ H ├───────────»
# «     └───┘└───┘  │                             │  └───┘└───┘ └───┘           »
# «q_4: ────────────┼─────────────────────────────┼─────────────────────────────»
# «                 │                             │                             »
# «q_5: ────────────┼─────────────────────────────┼─────────────────────────────»
# «     ┌───┐     ┌─┴─┐                         ┌─┴─┐┌───┐┌───┐┌─────┐┌───┐     »
# «q_6: ┤ H ├─────┤ X ├──■───────────────────■──┤ X ├┤ H ├┤ S ├┤ Sdg ├┤ H ├─────»
# «     └───┘     └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤├───┤└───┘└─────┘└───┘     »
# «q_7: ───────────────┤ X ├┤ Rz(-2*P[5]) ├┤ X ├┤ H ├┤ S ├──────────────────────»
# «                    └───┘└─────────────┘└───┘└───┘└───┘                      »
# «q_8: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «     ┌─────┐┌───┐                                                            »
# «q_0: ┤ Sdg ├┤ H ├──■─────────────────────────────────────────────────────────»
# «     └─────┘└───┘┌─┴─┐                                                       »
# «q_1: ────────────┤ X ├──■─────────────────────────────────────────────────■──»
# «                 └───┘┌─┴─┐                                             ┌─┴─┐»
# «q_2: ─────────────────┤ X ├──■───────────────────────────────────────■──┤ X ├»
# «                      └───┘┌─┴─┐                                   ┌─┴─┐├───┤»
# «q_3: ──────────────────────┤ X ├──■─────────────────────────────■──┤ X ├┤ H ├»
# «                           └───┘  │                             │  └───┘└───┘»
# «q_4: ─────────────────────────────┼─────────────────────────────┼────────────»
# «                                ┌─┴─┐                         ┌─┴─┐┌───┐┌───┐»
# «q_5: ───────────────────────────┤ X ├──■───────────────────■──┤ X ├┤ H ├┤ S ├»
# «                                └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤├───┤└───┘»
# «q_6: ────────────────────────────────┤ X ├┤ Rz(-2*P[6]) ├┤ X ├┤ H ├┤ S ├─────»
# «                                     └───┘└─────────────┘└───┘└───┘└───┘     »
# «q_7: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_8: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «            ┌───┐┌───┐┌───┐                                                  »
# «q_0: ───■───┤ H ├┤ S ├┤ H ├──────────────────────────────────────────────────»
# «      ┌─┴─┐ ├───┤└───┘└───┘                                                  »
# «q_1: ─┤ X ├─┤ H ├──■─────────────────────────────────────────────────────────»
# «     ┌┴───┴┐├───┤┌─┴─┐                                                       »
# «q_2: ┤ Sdg ├┤ H ├┤ X ├──■─────────────────────────────────────────────────■──»
# «     ├─────┤├───┤└───┘  │                                                 │  »
# «q_3: ┤ Sdg ├┤ H ├───────┼─────────────────────────────────────────────────┼──»
# «     └─────┘└───┘       │                                                 │  »
# «q_4: ───────────────────┼─────────────────────────────────────────────────┼──»
# «      ┌───┐           ┌─┴─┐                                             ┌─┴─┐»
# «q_5: ─┤ H ├───────────┤ X ├──■───────────────────────────────────────■──┤ X ├»
# «      └───┘           └───┘┌─┴─┐                                   ┌─┴─┐└───┘»
# «q_6: ──────────────────────┤ X ├──■─────────────────────────────■──┤ X ├─────»
# «                           └───┘┌─┴─┐                         ┌─┴─┐└───┘     »
# «q_7: ───────────────────────────┤ X ├──■───────────────────■──┤ X ├──────────»
# «                                └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤┌───┐     »
# «q_8: ────────────────────────────────┤ X ├┤ Rz(-2*P[7]) ├┤ X ├┤ H ├┤ H ├─────»
# «                                     └───┘└─────────────┘└───┘└───┘└───┘     »
# «                                                                            »
# «q_0: ───────────────────────────────────────────────────────────────────────»
# «           ┌───┐ ┌─────┐ ┌───┐                                              »
# «q_1: ──■───┤ H ├─┤ Sdg ├─┤ H ├──────────────────────────────────────────────»
# «     ┌─┴─┐ ├───┤ └┬───┬┘┌┴───┴┐┌───┐                                        »
# «q_2: ┤ X ├─┤ H ├──┤ S ├─┤ Sdg ├┤ H ├──■─────────────────────────────────────»
# «     └───┘ └───┘  └───┘ └─────┘└───┘┌─┴─┐                                   »
# «q_3: ───────────────────────────────┤ X ├──■────────────────────────────────»
# «                                    └───┘  │                                »
# «q_4: ──────────────────────────────────────┼────────────────────────────────»
# «     ┌───┐┌─────┐ ┌───┐                  ┌─┴─┐                              »
# «q_5: ┤ H ├┤ Sdg ├─┤ H ├──────────────────┤ X ├──■───────────────────────────»
# «     └───┘└─────┘ └───┘                  └───┘┌─┴─┐                         »
# «q_6: ─────────────────────────────────────────┤ X ├──■──────────────────────»
# «                                              └───┘┌─┴─┐                    »
# «q_7: ──────────────────────────────────────────────┤ X ├──■─────────────────»
# «                                                   └───┘┌─┴─┐┌─────────────┐»
# «q_8: ───────────────────────────────────────────────────┤ X ├┤ Rz(-2*P[8]) ├»
# «                                                        └───┘└─────────────┘»
# «                                                                    »
# «q_0: ───────────────────────────────────────────────────────────────»
# «                                                                    »
# «q_1: ──────────────────────────────────────────────────■────────────»
# «                                  ┌───┐ ┌───┐  ┌───┐ ┌─┴─┐          »
# «q_2: ──────────────────────────■──┤ H ├─┤ S ├──┤ H ├─┤ X ├──■───────»
# «                             ┌─┴─┐├───┤ ├───┤ ┌┴───┴┐├───┤  │       »
# «q_3: ────────────────────■───┤ X ├┤ H ├─┤ S ├─┤ Sdg ├┤ H ├──┼───────»
# «                         │   └───┘└───┘ └───┘ └─────┘└───┘  │       »
# «q_4: ────────────────────┼──────────────────────────────────┼───────»
# «                       ┌─┴─┐ ┌───┐┌───┐┌─────┐ ┌───┐      ┌─┴─┐     »
# «q_5: ─────────────■────┤ X ├─┤ H ├┤ S ├┤ Sdg ├─┤ H ├──────┤ X ├──■──»
# «                ┌─┴─┐ ┌┴───┴┐├───┤└───┘└─────┘ └───┘      └───┘┌─┴─┐»
# «q_6: ───────■───┤ X ├─┤ Sdg ├┤ H ├─────────────────────────────┤ X ├»
# «          ┌─┴─┐ └───┘ └─────┘└───┘                             └───┘»
# «q_7: ──■──┤ X ├─────────────────────────────────────────────────────»
# «     ┌─┴─┐├───┤┌─────┐ ┌───┐                                        »
# «q_8: ┤ X ├┤ H ├┤ Sdg ├─┤ H ├────────────────────────────────────────»
# «     └───┘└───┘└─────┘ └───┘                                        »
# «                                                                             »
# «q_0: ────────────────────────────────────────────■───────────────────────────»
# «                                   ┌───┐ ┌───┐ ┌─┴─┐                         »
# «q_1: ───────────────────────────■──┤ H ├─┤ S ├─┤ X ├──■──────────────────────»
# «                              ┌─┴─┐├───┤ └───┘ └───┘┌─┴─┐                    »
# «q_2: ──────────────────────■──┤ X ├┤ H ├────────────┤ X ├──■─────────────────»
# «                           │  └───┘└───┘            └───┘┌─┴─┐               »
# «q_3: ──────────────────────┼─────────────────────────────┤ X ├──■────────────»
# «                           │                             └───┘  │            »
# «q_4: ──────────────────────┼────────────────────────────────────┼────────────»
# «                         ┌─┴─┐┌───┐┌───┐┌─────┐┌───┐          ┌─┴─┐          »
# «q_5: ─────────────────■──┤ X ├┤ H ├┤ S ├┤ Sdg ├┤ H ├──────────┤ X ├──■───────»
# «     ┌─────────────┐┌─┴─┐├───┤├───┤└───┘└─────┘└───┘          └───┘┌─┴─┐     »
# «q_6: ┤ Rz(-2*P[9]) ├┤ X ├┤ H ├┤ S ├────────────────────────────────┤ X ├──■──»
# «     └─────────────┘└───┘└───┘└───┘                                └───┘┌─┴─┐»
# «q_7: ───────────────────────────────────────────────────────────────────┤ X ├»
# «                                                                        └───┘»
# «q_8: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «                                                              ┌───┐ ┌───┐     »
# «q_0: ─────────────────────────────────────────────────────■───┤ H ├─┤ H ├─────»
# «                                                        ┌─┴─┐┌┴───┴┐├───┤     »
# «q_1: ────────────────────────────────────────────────■──┤ X ├┤ Sdg ├┤ H ├──■──»
# «                                                   ┌─┴─┐├───┤└─────┘└───┘┌─┴─┐»
# «q_2: ───────────────────────────────────────────■──┤ X ├┤ H ├────────────┤ X ├»
# «                                              ┌─┴─┐├───┤├───┤┌─────┐┌───┐└───┘»
# «q_3: ──────────────────────────────────────■──┤ X ├┤ H ├┤ S ├┤ Sdg ├┤ H ├─────»
# «                                           │  └───┘└───┘└───┘└─────┘└───┘     »
# «q_4: ──────────────────────────────────────┼──────────────────────────────────»
# «                                         ┌─┴─┐┌───┐┌───┐                      »
# «q_5: ─────────────────────────────────■──┤ X ├┤ H ├┤ S ├──────────────────────»
# «                                    ┌─┴─┐├───┤└───┘└───┘                      »
# «q_6: ────────────────────────────■──┤ X ├┤ H ├────────────────────────────────»
# «                               ┌─┴─┐├───┤└───┘                                »
# «q_7: ──■────────────────────■──┤ X ├┤ H ├─────────────────────────────────────»
# «     ┌─┴─┐┌──────────────┐┌─┴─┐├───┤├───┤┌───┐                                »
# «q_8: ┤ X ├┤ Rz(-2*P[10]) ├┤ X ├┤ H ├┤ S ├┤ H ├────────────────────────────────»
# «     └───┘└──────────────┘└───┘└───┘└───┘└───┘                                »
# «                                                                              »
# «q_0: ─────────────────────────────────────────────────────────────────────────»
# «                                              ┌───┐ ┌───┐ ┌───┐               »
# «q_1: ──────────────────────────────────────■──┤ H ├─┤ S ├─┤ H ├──■────────────»
# «                                         ┌─┴─┐├───┤┌┴───┴┐├───┤┌─┴─┐          »
# «q_2: ──■──────────────────────────────■──┤ X ├┤ H ├┤ Sdg ├┤ H ├┤ X ├──■───────»
# «       │                              │  └───┘└───┘└─────┘└───┘└───┘  │       »
# «q_3: ──┼──────────────────────────────┼───────────────────────────────┼───────»
# «       │                              │                               │       »
# «q_4: ──┼──────────────────────────────┼───────────────────────────────┼───────»
# «       │                              │                               │       »
# «q_5: ──┼──────────────────────────────┼───────────────────────────────┼───────»
# «     ┌─┴─┐                          ┌─┴─┐┌───┐                        │       »
# «q_6: ┤ X ├──■────────────────────■──┤ X ├┤ H ├────────────────────────┼───────»
# «     └───┘┌─┴─┐┌──────────────┐┌─┴─┐├───┤├───┤                      ┌─┴─┐     »
# «q_7: ─────┤ X ├┤ Rz(-2*P[11]) ├┤ X ├┤ H ├┤ H ├──────────────────────┤ X ├──■──»
# «          └───┘└──────────────┘└───┘└───┘└───┘                      └───┘┌─┴─┐»
# «q_8: ────────────────────────────────────────────────────────────────────┤ X ├»
# «                                                                         └───┘»
# «                                                                      »
# «q_0: ──────────────────────────────────────────■──────────────────────»
# «                                       ┌───┐ ┌─┴─┐                    »
# «q_1: ─────────────────────────────■────┤ H ├─┤ X ├──■─────────────────»
# «                                ┌─┴─┐  ├───┤ ├───┤┌─┴─┐               »
# «q_2: ───────────────────────■───┤ X ├──┤ H ├─┤ S ├┤ X ├──■────────────»
# «                            │   └───┘  └───┘ └───┘└───┘┌─┴─┐          »
# «q_3: ───────────────────────┼──────────────────────────┤ X ├──■───────»
# «                            │                          └───┘  │       »
# «q_4: ───────────────────────┼─────────────────────────────────┼───────»
# «                            │                                 │       »
# «q_5: ───────────────────────┼─────────────────────────────────┼───────»
# «                            │                                 │       »
# «q_6: ───────────────────────┼─────────────────────────────────┼───────»
# «                          ┌─┴─┐ ┌───┐ ┌─────┐┌───┐          ┌─┴─┐     »
# «q_7: ──────────────────■──┤ X ├─┤ H ├─┤ Sdg ├┤ H ├──────────┤ X ├──■──»
# «     ┌──────────────┐┌─┴─┐├───┤┌┴───┴┐└┬───┬┘└───┘          └───┘┌─┴─┐»
# «q_8: ┤ Rz(-2*P[12]) ├┤ X ├┤ H ├┤ Sdg ├─┤ H ├─────────────────────┤ X ├»
# «     └──────────────┘└───┘└───┘└─────┘ └───┘                     └───┘»
# «                                                 ┌───┐                »
# «q_0: ───────────────────────────────────────■────┤ H ├────────────────»
# «                                          ┌─┴─┐  └───┘                »
# «q_1: ─────────────────────────────────■───┤ X ├───────────────────────»
# «                                    ┌─┴─┐┌┴───┴┐ ┌───┐                »
# «q_2: ────────────────────────────■──┤ X ├┤ Sdg ├─┤ H ├────────■───────»
# «                               ┌─┴─┐├───┤└┬───┬┘┌┴───┴┐┌───┐┌─┴─┐     »
# «q_3: ───────────────────────■──┤ X ├┤ H ├─┤ S ├─┤ Sdg ├┤ H ├┤ X ├──■──»
# «                            │  └───┘└───┘ └───┘ └─────┘└───┘└───┘┌─┴─┐»
# «q_4: ───────────────────────┼────────────────────────────────────┤ X ├»
# «                            │                                    └───┘»
# «q_5: ───────────────────────┼─────────────────────────────────────────»
# «                            │                                         »
# «q_6: ───────────────────────┼─────────────────────────────────────────»
# «                          ┌─┴─┐┌───┐┌───┐                             »
# «q_7: ──────────────────■──┤ X ├┤ H ├┤ S ├─────────────────────────────»
# «     ┌──────────────┐┌─┴─┐├───┤├───┤└───┘                             »
# «q_8: ┤ Rz(-2*P[13]) ├┤ X ├┤ H ├┤ S ├──────────────────────────────────»
# «     └──────────────┘└───┘└───┘└───┘                                  »
# «
# «q_0: ────────────────────────────────────
# «
# «q_1: ────────────────────────────────────
# «                               ┌───┐┌───┐
# «q_2: ───────────────────────■──┤ H ├┤ S ├
# «                          ┌─┴─┐├───┤├───┤
# «q_3: ──────────────────■──┤ X ├┤ H ├┤ S ├
# «     ┌──────────────┐┌─┴─┐├───┤├───┤└───┘
# «q_4: ┤ Rz(-2*P[14]) ├┤ X ├┤ H ├┤ S ├─────
# «     └──────────────┘└───┘└───┘└───┘
# «q_5: ────────────────────────────────────
# «
# «q_6: ────────────────────────────────────
# «
# «q_7: ────────────────────────────────────
# «
# «q_8: ────────────────────────────────────
# «

# %% [markdown]
# You can then start applying circuit optimization techniques to reduce the depth, for example using Qiskit's transpiler with ``optimization_level=3``:

# %%
from qiskit import transpile
qc.depth(), transpile(qc, optimization_level=3).depth()
# Out:
# (159, 120)
