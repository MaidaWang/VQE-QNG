# %% [markdown]
# # Example workflow using PBE and ADAPT-VQE
#
# > PBE = Projection-Based Embedding
#
# > ADAPT-VQE = Adaptive Derivative Assembled Pseudo-Trotter Variational Quantum Eigensolver
#
# - Choose a molecule to simulate, in this case $\mathrm{H}_2\mathrm{O}$
# - Embed some subdomain of the molecule, in this case one of the $\mathrm{O} - \mathrm{H}$ bonds.
# - Get the various objects required for a quantum simulation:
#     - The Hamiltonian whose ground state we are aiming to estimate;
#     - The Hartree-Fock state to use as reference to initialize our circuits;
#     - The cluster operator to define the excitations used in the ansatz circuit.
# - Then, run an ADAPT-VQE routine to iteratively build an ansatz circuit -- this approach has some favourable properties, for example we can control how deep the circuits get and it should be resilient to barren plateaus, since each ADAPT cycle is warm-started from the solution of the previous iteration.
# - We can also play various optimization tricks on the resulting circuits (e.g. with ZX calculus).
#
# ### We go through each of these steps below:

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning) 
import numpy as np
from pyscf import gto, scf, qmmm, fci, cc
from nbed.ham_builder import HamiltonianBuilder, get_coupled_cluster_operator
from nbed.utils import list_to_xyz
from nbed.driver import NbedDriver
from nbed.variational_optimization import ADAPT_VQE, VQE_Driver
from symmer import PauliwordOp, QubitTapering
from symmer.utils import exact_gs_energy
from symmer.evolution import PauliwordOp_to_QuantumCircuit

geom = [
    ("O",(0,0,0)),
    ("H",(0.952519,0,0)),
    ("H",(-0.246530058, 0.9200627021, 0))
]

# %% [markdown]
# Having defined the molecule geometry, use ``Nbed`` to perform projection-based embedding:

# %%
embed_mol = NbedDriver(
    geometry=list_to_xyz(geom), 
    n_active_atoms=2,
    basis='sto-3g', 
    xc_functional='cam-b3lyp',
    projector='mu',
    # run_qmmm=True,
    # mm_charges=charges,
    # mm_coords=coords,
    # max_dft_cycles=1000,
)
e_fci = fci.FCI(scf.RHF(embed_mol._build_mol()).run()).run().e_tot
emb_corr = (
    embed_mol.e_env 
    + embed_mol.two_e_cross 
    - embed_mol._mu["correction"] 
    - embed_mol._mu["beta_correction"]
) # embedding correction
e_pbe = embed_mol._run_emb_FCI(embed_mol.embedded_scf).e_tot + emb_corr
print(f'Full-system FCI energy: {e_fci}, Embedded FCI-in-DFT energy: {e_pbe}')
# Out:
# Warning: <pyscf.gto.mole.Mole object at 0x7fbe416ac430> must be initialized before calling SCF.
# Initialize <pyscf.gto.mole.Mole object at 0x7fbe416ac430> in <pyscf.dft.rks.RKS object at 0x7fbe416ac7c0>
# converged SCF energy = -74.9620396784632
# Full-system FCI energy: -75.0108466481692, Embedded FCI-in-DFT energy: -75.06236600840259

# %% [markdown]
# ``Nbed`` provides the functionality to extract the qubit Hamiltonian for the embedded region, which you may solve using your favourite eigensolver algorithm... note is might take a few second for a ``Ray`` instance to start up, which only happens once.

# %%
ham_builder = HamiltonianBuilder(embed_mol.embedded_scf, constant_e_shift=embed_mol._mu['nuc'])
H = PauliwordOp.from_openfermion(ham_builder.build(taper=False))
hf_state = ham_builder.get_hartree_fock_state()
QT = QubitTapering(H)
H = QT.taper_it(ref_state=hf_state)
hf_state = QT.tapered_ref_state
assert H.n_qubits == hf_state.n_qubits
#  0.00000000-0.00000445j ZIZYZXXIZ +
#  0.00000000+0.00000445j ZIZXZYXIZ +
#  0.00000000+0.00000445j ZIZXZXYIZ +
# -0.00000000-0.00000445j IIIYIYYZZ +
#  0.00000000+0.00000445j IIIYIXXZZ +
# -0.00000000-0.00000445j IIIXIYXZZ +
#  0.00000000+0.00000094j ZZZZIXIIY +
#  0.00000000+0.00000094j ZZZZIYIIX +
#  0.00000000+0.00000094j IZIZZIXYZ +
#  0.00000000+0.00000094j IZIZZIYXZ +
#  0.00000000+0.00000094j ZIZIZZXYI +
#  0.00000000+0.00000094j ZIZIZZYXI +
#  0.00000000-0.00000094j ZZZZIZXYZ +
#  0.00000000-0.00000094j ZZZZIZYXZ +
#  0.00000000+0.00000094j IIIIIXZZY +
#  0.00000000+0.00000094j IIIIIYZZX +
# -0.00000000-0.00000094j IZIZZXIZY +
# -0.00000000-0.00000094j IZIZZYIZX +
# -0.00000000-0.00000094j ZIZIZXZIY +
# -0.00000000-0.00000094j ZIZIZYZIX +
#  0.00000000-0.00000094j IIIIIIXYI +
#  0.00000000-0.00000094j IIIIIIYXI
# /home/maidaw/Downloads/QMMMbed-main/nbed/ham_builder.py:629: UserWarning: No Hartree-Fock state provided: assumed singlet configuration
#   warnings.warn('No Hartree-Fock state provided: assumed singlet configuration')

# %% [markdown]
# Now we have all the ingredients required to run an ADAPT-VQE routine, namely a Hamiltonian, a pool of excitation operators, and a reference state (for 15 ADAPT cycles this should take about 1 minute to run in this case, although you can play around with the various parameters in ADAPT_VQE.optimize):

# %%
adapt = ADAPT_VQE(
    observable = H,
    excitation_pool = CCSD_generator,
    ref_state = hf_state
)
adapt.topology_aware = False
adapt_result = adapt.optimize(max_cycles=15)
# Out:
# ---------------------------------------
# ADAPT cycle 1
#
# Largest pool derivative ∂P∂θ =  0.19036
#
# Selected excitation generator(s):
#
# 	YXIIIIIXX
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.263596812491244
# 	    |∆| = 0.19035773839857484
# Optimization step 1 :
# 	 Energy = -62.203120158971736
# 	    |∆| = 0.818064334870293
# Optimization step 2 :
# 	 Energy = -62.266976235353184
# 	    |∆| = 0.0011635017384961088
# Optimization step 3 :
# 	 Energy = -62.26697636145005
# 	    |∆| = 9.836694232490117e-07
#
# Energy at ADAPT cycle 1: -62.26698
#
# ---------------------------------------
# ADAPT cycle 2
#
# Largest pool derivative ∂P∂θ =  0.16680
#
# Selected excitation generator(s):
#
# 	IIXYIIIYY
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.266976361449935
# 	    |∆| = 0.16680278465550344
# Optimization step 1 :
# 	 Energy = -62.25040713479629
# 	    |∆| = 0.368139083306097
# Optimization step 2 :
# 	 Energy = -62.27133422171697
# 	    |∆| = 0.015899119222528065
# Optimization step 3 :
# 	 Energy = -62.270906854403044
# 	    |∆| = 0.06961108595002694
# Optimization step 4 :
# 	 Energy = -62.27135787963384
# 	    |∆| = 0.0003774236833656521
# Optimization step 5 :
# 	 Energy = -62.271357901681796
# 	    |∆| = 5.185101673991821e-07
#
# Energy at ADAPT cycle 2: -62.27136
#
# ---------------------------------------
# ADAPT cycle 3
#
# Largest pool derivative ∂P∂θ =  0.13261
#
# Selected excitation generator(s):
#
# 	XXIIIYXII
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.271357901681725
# 	    |∆| = 0.1326095552486682
# Optimization step 1 :
# 	 Energy = -62.24447970410358
# 	    |∆| = 0.5366656709274494
# Optimization step 2 :
# 	 Energy = -62.27309329786898
# 	    |∆| = 0.00606108210373725
# Optimization step 3 :
# 	 Energy = -62.27303123759567
# 	    |∆| = 0.02663561323577585
# Optimization step 4 :
# 	 Energy = -62.27309672742669
# 	    |∆| = 0.0005376119742778695
# Optimization step 5 :
# 	 Energy = -62.27309662300399
# 	    |∆| = 0.0009587517949616625
# Optimization step 6 :
# 	 Energy = -62.27309676254284
# 	    |∆| = 0.00020983955388743878
# Optimization step 7 :
# 	 Energy = -62.27309676690333
# 	    |∆| = 1.4254089050521952e-05
# Optimization step 8 :
# 	 Energy = -62.27309676692358
# 	    |∆| = 3.368458294868592e-11
#
# Energy at ADAPT cycle 3: -62.27310
#
# ---------------------------------------
# ADAPT cycle 4
#
# Largest pool derivative ∂P∂θ =  0.10263
#
# Selected excitation generator(s):
#
# 	IIXXIYXII
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.27309676692348
# 	    |∆| = 0.10263371123765097
# Optimization step 1 :
# 	 Energy = -62.26771262818427
# 	    |∆| = 0.21166470827203038
# Optimization step 2 :
# 	 Energy = -62.274839410055726
# 	    |∆| = 0.013162610263602905
# Optimization step 3 :
# 	 Energy = -62.27464656223494
# 	    |∆| = 0.04446065829413319
# Optimization step 4 :
# 	 Energy = -62.27485996138666
# 	    |∆| = 0.0031090608578801062
# Optimization step 5 :
# 	 Energy = -62.2748507024899
# 	    |∆| = 0.009171903087698217
# Optimization step 6 :
# 	 Energy = -62.27486119447082
# 	    |∆| = 0.00036186558063165767
# Optimization step 7 :
# 	 Energy = -62.27486099860432
# 	    |∆| = 0.001476762640139238
# Optimization step 8 :
# 	 Energy = -62.2748612066924
# 	    |∆| = 7.388559316340318e-05
# Optimization step 9 :
# 	 Energy = -62.27486120757901
# 	    |∆| = 1.3191821364650097e-06
#
# Energy at ADAPT cycle 4: -62.27486
#
# ---------------------------------------
# ADAPT cycle 5
#
# Largest pool derivative ∂P∂θ =  0.09680
#
# Selected excitation generator(s):
#
# 	YZZXIYYII
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.274861207578915
# 	    |∆| = 0.09680166762940023
# Optimization step 1 :
# 	 Energy = -62.2661868465522
# 	    |∆| = 0.27666738054987916
# Optimization step 2 :
# 	 Energy = -62.27607709442194
# 	    |∆| = 0.0067303688595813285
# Optimization step 3 :
# 	 Energy = -62.27604559648303
# 	    |∆| = 0.017216541372476114
# Optimization step 4 :
# 	 Energy = -62.27608379512766
# 	    |∆| = 0.001803928991572438
# Optimization step 5 :
# 	 Energy = -62.276080022401345
# 	    |∆| = 0.006073962153686027
# Optimization step 6 :
# 	 Energy = -62.27608417127515
# 	    |∆| = 0.00023975584973694988
# Optimization step 7 :
# 	 Energy = -62.27608412070475
# 	    |∆| = 0.000704991925671149
# Optimization step 8 :
# 	 Energy = -62.27608417846709
# 	    |∆| = 7.028417009920254e-05
# Optimization step 9 :
# 	 Energy = -62.276084174463264
# 	    |∆| = 0.0002048802742609608
# Optimization step 10:
# 	 Energy = -62.2760841789078
# 	    |∆| = 3.110920496389898e-05
# Optimization step 11:
# 	 Energy = -62.276084179031194
# 	    |∆| = 3.49676397407845e-06
#
# Energy at ADAPT cycle 5: -62.27608
#
# ---------------------------------------
# ADAPT cycle 6
#
# Largest pool derivative ∂P∂θ =  0.10061
#
# Selected excitation generator(s):
#
# 	XZZXIIYXI
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.27608417903112
# 	    |∆| = 0.10061115765502374
# Optimization step 1 :
# 	 Energy = -62.2666149184513
# 	    |∆| = 0.2889930863211025
# Optimization step 2 :
# 	 Energy = -62.27739096051425
# 	    |∆| = 0.005454167259449919
# Optimization step 3 :
# 	 Energy = -62.277361699799
# 	    |∆| = 0.01660275205760782
# Optimization step 4 :
# 	 Energy = -62.27739472187926
# 	    |∆| = 0.0009418024530902202
# Optimization step 5 :
# 	 Energy = -62.27739355811689
# 	    |∆| = 0.0034865162238407054
# Optimization step 6 :
# 	 Energy = -62.277394816756335
# 	    |∆| = 0.0001598317730437731
# Optimization step 7 :
# 	 Energy = -62.27739479682905
# 	    |∆| = 0.0004396902850373873
# Optimization step 8 :
# 	 Energy = -62.27739481960973
# 	    |∆| = 5.730690688362714e-05
# Optimization step 9 :
# 	 Energy = -62.27739481923952
# 	    |∆| = 8.528450098986668e-05
# Optimization step 10:
# 	 Energy = -62.277394819862614
# 	    |∆| = 3.571869619605639e-05
# Optimization step 11:
# 	 Energy = -62.27739481993444
# 	    |∆| = 2.5928802681435584e-05
# Optimization step 12:
# 	 Energy = -62.27739482000624
# 	    |∆| = 9.869122290296004e-06
#
# Energy at ADAPT cycle 6: -62.27739
#
# ---------------------------------------
# ADAPT cycle 7
#
# Largest pool derivative ∂P∂θ =  0.10005
#
# Selected excitation generator(s):
#
# 	IIYYIIYXI
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.27739482000612
# 	    |∆| = 0.1000479728651768
# Optimization step 1 :
# 	 Energy = -62.27226810583926
# 	    |∆| = 0.20332282069838523
# Optimization step 2 :
# 	 Energy = -62.279049616799966
# 	    |∆| = 0.007155235263017766
# Optimization step 3 :
# 	 Energy = -62.27900469382126
# 	    |∆| = 0.01980405678174118
# Optimization step 4 :
# 	 Energy = -62.2790564490844
# 	    |∆| = 0.0005218485636972538
# Optimization step 5 :
# 	 Energy = -62.279056223575864
# 	    |∆| = 0.0014212815523427693
# Optimization step 6 :
# 	 Energy = -62.279056485961874
# 	    |∆| = 8.977151832015099e-05
# Optimization step 7 :
# 	 Energy = -62.27905647756365
# 	    |∆| = 0.0003015633549798711
# Optimization step 8 :
# 	 Energy = -62.279056486772994
# 	    |∆| = 3.340867813394402e-05
# Optimization step 9 :
# 	 Energy = -62.27905648667829
# 	    |∆| = 4.650327855979936e-05
# Optimization step 10:
# 	 Energy = -62.27905648688969
# 	    |∆| = 1.9228262132830412e-05
# Optimization step 11:
# 	 Energy = -62.27905648687082
# 	    |∆| = 2.4754515975974946e-05
# Optimization step 12:
# 	 Energy = -62.279056486938295
# 	    |∆| = 7.073325988422103e-06
#
# Energy at ADAPT cycle 7: -62.27906
#
# ---------------------------------------
# ADAPT cycle 8
#
# Largest pool derivative ∂P∂θ =  0.09717
#
# Selected excitation generator(s):
#
# 	IYYIIXZZY
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.27905648693817
# 	    |∆| = 0.09717450587992389
# Optimization step 1 :
# 	 Energy = -62.27016319346416
# 	    |∆| = 0.2800429823364943
# Optimization step 2 :
# 	 Energy = -62.280271576530694
# 	    |∆| = 0.003745797885738451
# Optimization step 3 :
# 	 Energy = -62.28025470716264
# 	    |∆| = 0.013395314408124973
# Optimization step 4 :
# 	 Energy = -62.28027317342066
# 	    |∆| = 0.000936097848843175
# Optimization step 5 :
# 	 Energy = -62.28027238968971
# 	    |∆| = 0.00267225619529814
# Optimization step 6 :
# 	 Energy = -62.28027328798756
# 	    |∆| = 0.00015677075634854118
# Optimization step 7 :
# 	 Energy = -62.280273266187116
# 	    |∆| = 0.00047491709030709236
# Optimization step 8 :
# 	 Energy = -62.28027329070126
# 	    |∆| = 5.819576543939971e-05
# Optimization step 9 :
# 	 Energy = -62.28027328979397
# 	    |∆| = 0.00010186840805286905
# Optimization step 10:
# 	 Energy = -62.28027329100424
# 	    |∆| = 3.102830631820622e-05
# Optimization step 11:
# 	 Energy = -62.280273291092314
# 	    |∆| = 1.7240757183711528e-05
# Optimization step 12:
# 	 Energy = -62.28027329107072
# 	    |∆| = 2.1261783409919776e-05
# Optimization step 13:
# 	 Energy = -62.28027329111783
# 	    |∆| = 9.315533878434826e-06
#
# Energy at ADAPT cycle 8: -62.28027
#
# ---------------------------------------
# ADAPT cycle 9
#
# Largest pool derivative ∂P∂θ =  0.09853
#
# Selected excitation generator(s):
#
# 	IYXIIYYII
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.28027329111776
# 	    |∆| = 0.09852503866211455
# Optimization step 1 :
# 	 Energy = -62.2711899023876
# 	    |∆| = 0.2853368169293645
# Optimization step 2 :
# 	 Energy = -62.28152628955103
# 	    |∆| = 0.010432848144760656
# Optimization step 3 :
# 	 Energy = -62.28142923701083
# 	    |∆| = 0.02980771664438169
# Optimization step 4 :
# 	 Energy = -62.281540723994134
# 	    |∆| = 0.00178178292229023
# Optimization step 5 :
# 	 Energy = -62.28153745551054
# 	    |∆| = 0.005779301476682587
# Optimization step 6 :
# 	 Energy = -62.281541113941145
# 	    |∆| = 0.00047533277701734556
# Optimization step 7 :
# 	 Energy = -62.28154090569348
# 	    |∆| = 0.001378899020601245
# Optimization step 8 :
# 	 Energy = -62.28154114263168
# 	    |∆| = 7.883153704751028e-05
# Optimization step 9 :
# 	 Energy = -62.28154113796212
# 	    |∆| = 0.00022860819304419672
# Optimization step 10:
# 	 Energy = -62.28154114315908
# 	    |∆| = 3.982009147895871e-05
# Optimization step 11:
# 	 Energy = -62.28154114323246
# 	    |∆| = 3.098278102485315e-05
# Optimization step 12:
# 	 Energy = -62.2815411433266
# 	    |∆| = 1.563112208198999e-05
# Optimization step 13:
# 	 Energy = -62.281541143337606
# 	    |∆| = 1.210322363912213e-05
#
# Energy at ADAPT cycle 9: -62.28154
#
# ---------------------------------------
# ADAPT cycle 10
#
# Largest pool derivative ∂P∂θ =  0.09539
#
# Selected excitation generator(s):
#
# 	IIYYIYZZX
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.28154114333749
# 	    |∆| = 0.09539227981771552
# Optimization step 1 :
# 	 Energy = -62.27673965140274
# 	    |∆| = 0.1982814929201481
# Optimization step 2 :
# 	 Energy = -62.28303024520626
# 	    |∆| = 0.009985125858082618
# Optimization step 3 :
# 	 Energy = -62.28295715656613
# 	    |∆| = 0.02497086832639802
# Optimization step 4 :
# 	 Energy = -62.28304466175039
# 	    |∆| = 0.0011807834043893093
# Optimization step 5 :
# 	 Energy = -62.28304364467641
# 	    |∆| = 0.0029354378908984565
# Optimization step 6 :
# 	 Energy = -62.2830448628735
# 	    |∆| = 0.00012952981767384346
# Optimization step 7 :
# 	 Energy = -62.28304484760248
# 	    |∆| = 0.00039316995421557045
# Optimization step 8 :
# 	 Energy = -62.283044864803614
# 	    |∆| = 4.3353724946615436e-05
# Optimization step 9 :
# 	 Energy = -62.28304486422578
# 	    |∆| = 8.423405851998278e-05
# Optimization step 10:
# 	 Energy = -62.28304486498401
# 	    |∆| = 2.4198338527142216e-05
# Optimization step 11:
# 	 Energy = -62.28304486503726
# 	    |∆| = 1.8114105047077637e-05
# Optimization step 12:
# 	 Energy = -62.2830448650182
# 	    |∆| = 2.2920307286061834e-05
# Optimization step 13:
# 	 Energy = -62.28304486506001
# 	    |∆| = 9.839687296789946e-06
#
# Energy at ADAPT cycle 10: -62.28304
#
# ---------------------------------------
# ADAPT cycle 11
#
# Largest pool derivative ∂P∂θ =  0.08604
#
# Selected excitation generator(s):
#
# 	IXXIIIXYI
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.28304486505993
# 	    |∆| = 0.08604343580030381
# Optimization step 1 :
# 	 Energy = -62.276002780218235
# 	    |∆| = 0.25244108128407
# Optimization step 2 :
# 	 Energy = -62.283993046532814
# 	    |∆| = 0.00971591016295661
# Optimization step 3 :
# 	 Energy = -62.28390775314366
# 	    |∆| = 0.02789838383959672
# Optimization step 4 :
# 	 Energy = -62.284005475341836
# 	    |∆| = 0.0015528909604377583
# Optimization step 5 :
# 	 Energy = -62.28400306260595
# 	    |∆| = 0.0050139363547984615
# Optimization step 6 :
# 	 Energy = -62.28400577594998
# 	    |∆| = 0.0004637102414002801
# Optimization step 7 :
# 	 Energy = -62.2840055633335
# 	    |∆| = 0.0013982009309197068
# Optimization step 8 :
# 	 Energy = -62.28400580257451
# 	    |∆| = 6.105247643440557e-05
# Optimization step 9 :
# 	 Energy = -62.284005800494874
# 	    |∆| = 0.00014331553769036611
# Optimization step 10:
# 	 Energy = -62.28400580294281
# 	    |∆| = 2.812834590329835e-05
# Optimization step 11:
# 	 Energy = -62.28400580302188
# 	    |∆| = 1.2942964426688603e-05
#
# Energy at ADAPT cycle 11: -62.28401
#
# ---------------------------------------
# ADAPT cycle 12
#
# Largest pool derivative ∂P∂θ =  0.08643
#
# Selected excitation generator(s):
#
# 	YZZYIYZZX
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.28400580302177
# 	    |∆| = 0.08643473592811271
# Optimization step 1 :
# 	 Energy = -62.27690271865878
# 	    |∆| = 0.2534827023206081
# Optimization step 2 :
# 	 Energy = -62.28496283609266
# 	    |∆| = 0.009750569468991537
# Optimization step 3 :
# 	 Energy = -62.28487514513509
# 	    |∆| = 0.028612498078001133
# Optimization step 4 :
# 	 Energy = -62.28497523482292
# 	    |∆| = 0.0018363701185190213
# Optimization step 5 :
# 	 Energy = -62.28497147658731
# 	    |∆| = 0.0062033539903322155
# Optimization step 6 :
# 	 Energy = -62.28497563295579
# 	    |∆| = 0.0004329873680447811
# Optimization step 7 :
# 	 Energy = -62.28497545666358
# 	    |∆| = 0.001292183174188521
# Optimization step 8 :
# 	 Energy = -62.2849756567002
# 	    |∆| = 9.073719126121383e-05
# Optimization step 9 :
# 	 Energy = -62.28497565052871
# 	    |∆| = 0.00023761743139702823
# Optimization step 10:
# 	 Energy = -62.284975657653966
# 	    |∆| = 2.8282405470341172e-05
# Optimization step 11:
# 	 Energy = -62.284975657710994
# 	    |∆| = 2.040447016618347e-05
# Optimization step 12:
# 	 Energy = -62.28497565772811
# 	    |∆| = 1.5038273885677974e-05
# Optimization step 13:
# 	 Energy = -62.28497565774957
# 	    |∆| = 6.408436023644425e-06
#
# Energy at ADAPT cycle 12: -62.28498
#
# ---------------------------------------
# ADAPT cycle 13
#
# Largest pool derivative ∂P∂θ =  0.07865
#
# Selected excitation generator(s):
#
# 	XXIIIXZZY
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.2849756577495
# 	    |∆| = 0.07865346827368053
# Optimization step 1 :
# 	 Energy = -62.27513193256284
# 	    |∆| = 0.3302502856540247
# Optimization step 2 :
# 	 Energy = -62.28557210267342
# 	    |∆| = 0.006452331153046561
# Optimization step 3 :
# 	 Energy = -62.285517466827315
# 	    |∆| = 0.024365794963650992
# Optimization step 4 :
# 	 Energy = -62.28557661870775
# 	    |∆| = 0.0014828476251081294
# Optimization step 5 :
# 	 Energy = -62.28557452581996
# 	    |∆| = 0.004418604709972399
# Optimization step 6 :
# 	 Energy = -62.28557689975374
# 	    |∆| = 0.00025722730677961794
# Optimization step 7 :
# 	 Energy = -62.28557684496492
# 	    |∆| = 0.0006958616595508908
# Optimization step 8 :
# 	 Energy = -62.285576908396244
# 	    |∆| = 4.5388845705442274e-05
# Optimization step 9 :
# 	 Energy = -62.28557690798143
# 	    |∆| = 6.992479370478216e-05
# Optimization step 10:
# 	 Energy = -62.28557690857139
# 	    |∆| = 2.506646852308448e-05
# Optimization step 11:
# 	 Energy = -62.285576908554745
# 	    |∆| = 2.6635607679603372e-05
# Optimization step 12:
# 	 Energy = -62.28557690861552
# 	    |∆| = 1.2423667077267471e-05
#
# Energy at ADAPT cycle 13: -62.28558
#
# ---------------------------------------
# ADAPT cycle 14
#
# Largest pool derivative ∂P∂θ =  0.07550
#
# Selected excitation generator(s):
#
# 	YYIIIIXYI
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.28557690861538
# 	    |∆| = 0.0754958642135745
# Optimization step 1 :
# 	 Energy = -62.27649872675281
# 	    |∆| = 0.3176955705543816
# Optimization step 2 :
# 	 Energy = -62.28612612214983
# 	    |∆| = 0.006944866204637005
# Optimization step 3 :
# 	 Energy = -62.286055420405994
# 	    |∆| = 0.028448790838849825
# Optimization step 4 :
# 	 Energy = -62.28613102776353
# 	    |∆| = 0.0016233815367220291
# Optimization step 5 :
# 	 Energy = -62.28612880614537
# 	    |∆| = 0.004458892960258785
# Optimization step 6 :
# 	 Energy = -62.28613138482866
# 	    |∆| = 0.00025514078238687355
# Optimization step 7 :
# 	 Energy = -62.28613132923178
# 	    |∆| = 0.0007076140602933059
# Optimization step 8 :
# 	 Energy = -62.286131393290574
# 	    |∆| = 4.768692362803618e-05
# Optimization step 9 :
# 	 Energy = -62.286131392283664
# 	    |∆| = 0.00010271584571506152
# Optimization step 10:
# 	 Energy = -62.28613139349997
# 	    |∆| = 2.4604879538698377e-05
# Optimization step 11:
# 	 Energy = -62.286131393459044
# 	    |∆| = 2.8919992696230883e-05
# Optimization step 12:
# 	 Energy = -62.28613139354004
# 	    |∆| = 1.3321211153000256e-05
# Optimization step 13:
# 	 Energy = -62.286131393541204
# 	    |∆| = 1.2969877097140755e-05
# Optimization step 14:
# 	 Energy = -62.2861313935585
# 	    |∆| = 2.0517879070881353e-06
#
# Energy at ADAPT cycle 14: -62.28613
#
# ---------------------------------------
# ADAPT cycle 15
#
# Largest pool derivative ∂P∂θ =  0.07058
#
# Selected excitation generator(s):
#
# 	IIIIYYYII
#
#  ---------------------------------------
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -62.286131393558435
# 	    |∆| = 0.07058003749568251
# Optimization step 1 :
# 	 Energy = -62.28499660291226
# 	    |∆| = 0.10513775578829673
# Optimization step 2 :
# 	 Energy = -62.28714593817843
# 	    |∆| = 0.00879974239385356
# Optimization step 3 :
# 	 Energy = -62.28703094368224
# 	    |∆| = 0.03532968429173841
# Optimization step 4 :
# 	 Energy = -62.28715373158503
# 	    |∆| = 0.0010589298383463593
# Optimization step 5 :
# 	 Energy = -62.287152602278844
# 	    |∆| = 0.00347856742354103
# Optimization step 6 :
# 	 Energy = -62.28715387118169
# 	    |∆| = 0.0003447566383844805
# Optimization step 7 :
# 	 Energy = -62.287153744271585
# 	    |∆| = 0.0011058023223879127
# Optimization step 8 :
# 	 Energy = -62.28715388550387
# 	    |∆| = 5.71224109048248e-05
# Optimization step 9 :
# 	 Energy = -62.28715388215739
# 	    |∆| = 0.00018079764904934604
# Optimization step 10:
# 	 Energy = -62.28715388587797
# 	    |∆| = 1.3871437898879079e-05
# Optimization step 11:
# 	 Energy = -62.287153885871334
# 	    |∆| = 1.7915650816490188e-05
# Optimization step 12:
# 	 Energy = -62.287153885902235
# 	    |∆| = 8.057646656069974e-06
#
# Energy at ADAPT cycle 15: -62.28715

# %%
# 获取最终生成的量子线路

final_circuit = PauliwordOp_to_QuantumCircuit(
    PauliwordOp.from_list(adapt_result['adapt_operator']), 
    bind_params=False,
    include_barriers=False
)

result, history = adapt.run()  # 这里设置最大步数为100
 # 使用CG优化方法
# Out:
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -58.32079642099683
# 	    |∆| = 3.1904123817120396
# Optimization step 1 :
# 	 Energy = -60.21131379182088
# 	    |∆| = 1.0349610569908976
# Optimization step 2 :
# 	 Energy = -59.83704808688419
# Process Process-745:
# Process Process-744:
# Process Process-746:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/process_handler.py", line 67, in _func
#     data_out = func(iter, shared)
# Traceback (most recent call last):
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/process_handler.py", line 67, in _func
#     data_out = func(iter, shared)
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/process_handler.py", line 100, in <lambda>
#     _func = lambda iter,shared: [func(i, shared) for i in iter]
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/process_handler.py", line 100, in <lambda>
#     _func = lambda iter,shared: [func(i, shared) for i in iter]
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/process_handler.py", line 100, in <listcomp>
#     _func = lambda iter,shared: [func(i, shared) for i in iter]
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/process_handler.py", line 100, in <listcomp>
#     _func = lambda iter,shared: [func(i, shared) for i in iter]
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 238, in f
#     return self.partial_derivative(param,index)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 238, in f
#     return self.partial_derivative(param,index)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/process_handler.py", line 67, in _func
#     data_out = func(iter, shared)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 223, in partial_derivative
#     return self.f(x_upper) - self.f(x_lower)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 207, in f
#     return self._f(self.observable, state)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 223, in partial_derivative
#     return self.f(x_upper) - self.f(x_lower)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 189, in _f
#     return (state.dagger * observable * state).real
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 207, in f
#     return self._f(self.observable, state)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/process_handler.py", line 100, in <lambda>
#     _func = lambda iter,shared: [func(i, shared) for i in iter]
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py", line 1826, in __mul__
#     new_bra_state = QuantumState(
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 189, in _f
#     return (state.dagger * observable * state).real
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/process_handler.py", line 100, in <listcomp>
#     _func = lambda iter,shared: [func(i, shared) for i in iter]
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py", line 1623, in __init__
#     self.state_op = PauliwordOp(symp_matrix, coeff_vector)
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py", line 1826, in __mul__
#     new_bra_state = QuantumState(
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py", line 1623, in __init__
#     self.state_op = PauliwordOp(symp_matrix, coeff_vector)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 238, in f
#     return self.partial_derivative(param,index)
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py", line 57, in __init__
#     assert(set(np.unique(symp_matrix)).issubset({0,1})), 'symplectic matrix not defined with 0 and 1 only'
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py", line 57, in __init__
#     assert(set(np.unique(symp_matrix)).issubset({0,1})), 'symplectic matrix not defined with 0 and 1 only'
#   File "<__array_function__ internals>", line 180, in unique
#   File "<__array_function__ internals>", line 180, in unique
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 223, in partial_derivative
#     return self.f(x_upper) - self.f(x_lower)
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 272, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 272, in unique
#     ret = _unique1d(ar, return_index, return_inverse, return_counts)
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 207, in f
#     return self._f(self.observable, state)
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 333, in _unique1d
#     ar.sort()
# KeyboardInterrupt
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/numpy/lib/arraysetops.py", line 333, in _unique1d
#     ar.sort()
# KeyboardInterrupt
#   File "/home/maidaw/Downloads/QMMMbed-main/nbed/variational_optimization.py", line 189, in _f
#     return (state.dagger * observable * state).real
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py", line 1824, in __mul__
#     new_state_op = self.state_op * mul_obj
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py", line 867, in __mul__
#     pauli_mult_out = PwordOp.dagger._multiply_by_operator(
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py", line 813, in _multiply_by_operator
#     *symplectic_cleanup(
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/utils.py", line 148, in symplectic_cleanup
#     re_order_indices = np.argsort(symp_matrix_view.ravel())
#   File "<__array_function__ internals>", line 180, in argsort
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 1120, in argsort
#     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#   File "/home/maidaw/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/numpy/core/fromnumeric.py", line 57, in _wrapfunc
#     return bound(*args, **kwds)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 9
#       1 # 获取最终生成的量子线路
#       3 final_circuit = PauliwordOp_to_QuantumCircuit(
#       4     PauliwordOp.from_list(adapt_result['adapt_operator']),
#       5     bind_params=False,
#       6     include_barriers=False
#       7 )
# ----> 9 result, history = adapt.run()  # 这里设置最大步数为100
#      10  # 使用CG优化方法
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:410, in VQE_Driver.run(self, x0, **kwargs)
#     408 if self.verbose:
#     409     print('VQE simulation commencing...\n')
# --> 410 opt_out = minimize(
#     411     fun=fun, jac=jac, x0=x0, **kwargs
#     412 )
#     413 return serialize_opt_data(opt_out), vqe_history
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_minimize.py:691, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     689     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     690 elif meth == 'bfgs':
# --> 691     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#     692 elif meth == 'newton-cg':
#     693     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     694                              **options)
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_optimize.py:1388, in _minimize_bfgs(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, xrtol, **unknown_options)
#    1385 pk = -np.dot(Hk, gfk)
#    1386 try:
#    1387     alpha_k, fc, gc, old_fval, old_old_fval, gfkp1 = \
# -> 1388              _line_search_wolfe12(f, myfprime, xk, pk, gfk,
#    1389                                   old_fval, old_old_fval, amin=1e-100, amax=1e100)
#    1390 except _LineSearchError:
#    1391     # Line search failed to find a better solution.
#    1392     warnflag = 2
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_optimize.py:1160, in _line_search_wolfe12(f, fprime, xk, pk, gfk, old_fval, old_old_fval, **kwargs)
#    1146 """
#    1147 Same as line_search_wolfe1, but fall back to line_search_wolfe2 if
#    1148 suitable step length is not found, and raise an exception if a
#    (...)
#    1155
#    1156 """
#    1158 extra_condition = kwargs.pop('extra_condition', None)
# -> 1160 ret = line_search_wolfe1(f, fprime, xk, pk, gfk,
#    1161                          old_fval, old_old_fval,
#    1162                          **kwargs)
#    1164 if ret[0] is not None and extra_condition is not None:
#    1165     xp1 = xk + ret[0] * pk
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_linesearch.py:84, in line_search_wolfe1(f, fprime, xk, pk, gfk, old_fval, old_old_fval, args, c1, c2, amax, amin, xtol)
#      80     return np.dot(gval[0], pk)
#      82 derphi0 = np.dot(gfk, pk)
# ---> 84 stp, fval, old_fval = scalar_search_wolfe1(
#      85         phi, derphi, old_fval, old_old_fval, derphi0,
#      86         c1=c1, c2=c2, amax=amax, amin=amin, xtol=xtol)
#      88 return stp, fc[0], gc[0], fval, old_fval, gval[0]
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_linesearch.py:161, in scalar_search_wolfe1(phi, derphi, phi0, old_phi0, derphi0, c1, c2, amax, amin, xtol)
#     159     alpha1 = stp
#     160     phi1 = phi(stp)
# --> 161     derphi1 = derphi(stp)
#     162 else:
#     163     break
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_linesearch.py:78, in line_search_wolfe1.<locals>.derphi(s)
#      77 def derphi(s):
# ---> 78     gval[0] = fprime(xk + s*pk, *args)
#      79     gc[0] += 1
#      80     return np.dot(gval[0], pk)
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:273, in ScalarFunction.grad(self, x)
#     271 if not np.array_equal(x, self.x):
#     272     self._update_x_impl(x)
# --> 273 self._update_grad()
#     274 return self.g
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:256, in ScalarFunction._update_grad(self)
#     254 def _update_grad(self):
#     255     if not self.g_updated:
# --> 256         self._update_grad_impl()
#     257         self.g_updated = True
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:167, in ScalarFunction.__init__.<locals>.update_grad()
#     166 def update_grad():
# --> 167     self.g = grad_wrapped(self.x)
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/scipy/optimize/_differentiable_functions.py:164, in ScalarFunction.__init__.<locals>.grad_wrapped(x)
#     162 def grad_wrapped(x):
#     163     self.ngev += 1
# --> 164     return np.atleast_1d(grad(np.copy(x), *args))
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:402, in VQE_Driver.run.<locals>.jac(x)
#     400 def jac(x):
#     401     counter = get_counter(increment=False)
# --> 402     grad    = self.gradient(x)
#     403     vqe_history['gradient'][counter] = tuple(grad)
#     404     if self.verbose:
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:239, in VQE_Driver.gradient(self, x)
#     236     @process.parallelize
#     237     def f(index, param):
#     238         return self.partial_derivative(param,index)
# --> 239     grad_vec = f(range(self.circuit.num_parameters), x)
#     241 else:
#     242     grad_vec = [self.partial_derivative(x, i) for i in range(self.circuit.num_parameters)]
#
# File ~/Downloads/QMMMbed-main/nbed/process_handler.py:103, in ProcessHandler.parallelize.<locals>.wrapper(iter, shared)
#     100 _func = lambda iter,shared: [func(i, shared) for i in iter]
#     102 if self.method   == 'mp':
# --> 103     return self._process_mp(_func, iter, shared)
#     104 elif self.method == 'ray':
#     105     return self._process_ray(_func, iter, shared)
#
# File ~/Downloads/QMMMbed-main/nbed/process_handler.py:80, in ProcessHandler._process_mp(self, func, iter, shared)
#      78 data = []
#      79 for _ in range(self.n_chunks):
# ---> 80     data.append(queue.get())
#      81 # complete the processes
#      82 for proc in procs:
#
# File /usr/lib/python3.8/multiprocessing/queues.py:97, in Queue.get(self, block, timeout)
#      95 if block and timeout is None:
#      96     with self._rlock:
# ---> 97         res = self._recv_bytes()
#      98     self._sem.release()
#      99 else:
#
# File /usr/lib/python3.8/multiprocessing/connection.py:216, in _ConnectionBase.recv_bytes(self, maxlength)
#     214 if maxlength is not None and maxlength < 0:
#     215     raise ValueError("negative maxlength")
# --> 216 buf = self._recv_bytes(maxlength)
#     217 if buf is None:
#     218     self._bad_message_length()
#
# File /usr/lib/python3.8/multiprocessing/connection.py:414, in Connection._recv_bytes(self, maxsize)
#     413 def _recv_bytes(self, maxsize=None):
# --> 414     buf = self._recv(4)
#     415     size, = struct.unpack("!i", buf.getvalue())
#     416     if size == -1:
#
# File /usr/lib/python3.8/multiprocessing/connection.py:379, in Connection._recv(self, size, read)
#     377 remaining = size
#     378 while remaining > 0:
# --> 379     chunk = read(handle, remaining)
#     380     n = len(chunk)
#     381     if n == 0:
#
# KeyboardInterrupt:

# %%
# 遍历每种优化方法并运行VQE
import matplotlib.pyplot as plt

x_values = adapt_result['result']['x']
# Create a new array of zeros with the same shape as x_values
x_zeros = [0.0] * len(x_values)
x_random = np.random.rand(len(x_values))
# 定义需要比较的优化方法'BFGS', 'CG', 'SLSQP', 
methods = ['BFGS', 'CG', 'SLSQP','NaturalGradient']
result_histories = {}

# 遍历每种优化方法并运行VQE
for method in methods:
    if method == 'NaturalGradient':
        print(f'We are using "{method}" now.')
        result, history = adapt.run_with_gradient_descent(x0 = x_random, max_steps=50, learning_rate= 0.1)  # 这里设置最大步数为100
    else:
        # 运行ADAPT_VQE中的方法
        print(f'We are using "{method}" now.')

        result, history = adapt.run(x0 = x_random,method=method, options={'maxiter': 10})
    
    result_histories[method] = history

# 画出能量随迭代次数变化的图像
plt.figure(figsize=(10, 6))

for method in methods:
    energy_history = [result_histories[method]['energy'][i] for i in result_histories[method]['energy']]
    plt.plot(energy_history, label=method)

plt.xlabel('Iteration')
plt.ylabel('Energy')
plt.title('Energy Optimization with Different Methods')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# We are using "BFGS" now.
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -59.0544269273677
# 	    |∆| = 2.6008017884409314
# Optimization step 1 :
# 	 Energy = -60.175551334475486
# 	    |∆| = 1.7110071513244691
# Optimization step 2 :
# 	 Energy = -58.839032198329086
# 	    |∆| = 3.753081572504847
# Optimization step 3 :
# 	 Energy = -60.48444911266617
# 	    |∆| = 0.9219580585622612
# Optimization step 4 :
# 	 Energy = -60.72448666623979
# 	    |∆| = 1.3475918748524607
# Optimization step 5 :
# 	 Energy = -60.829888041721446
# 	    |∆| = 1.5039825317341466
# Optimization step 6 :
# 	 Energy = -60.95208369354838
# 	    |∆| = 0.8203300083197386
# Optimization step 7 :
# 	 Energy = -60.978708139661414
# 	    |∆| = 1.0759650721894878
# Optimization step 8 :
# 	 Energy = -61.02689168754729
# 	    |∆| = 0.8380523584722792
# Optimization step 9 :
# 	 Energy = -61.11020154461823
# 	    |∆| = 0.675556799125023
# Optimization step 10:
# 	 Energy = -61.21190166987724
# 	    |∆| = 0.7700510571532828
# Optimization step 11:
# 	 Energy = -61.049957294401175
# 	    |∆| = 1.567828191441714
# Optimization step 12:
# 	 Energy = -61.24708362242506
# 	    |∆| = 0.6196404360248873
# We are using "CG" now.
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -59.0544269273677
# 	    |∆| = 2.6008017884409314
# Optimization step 1 :
# 	 Energy = -60.175551334475486
# 	    |∆| = 1.7110071513244691
# Optimization step 2 :
# 	 Energy = -58.889680105528164
# 	    |∆| = 3.5984787867817483
# Optimization step 3 :
# 	 Energy = -60.48898994525222
# 	    |∆| = 0.9095335912371617
# Optimization step 4 :
# 	 Energy = -60.70585155101682
# 	    |∆| = 1.4347975471681822
# Optimization step 5 :
# 	 Energy = -60.756482982729686
# 	    |∆| = 0.8789604137990804
# Optimization step 6 :
# 	 Energy = -60.71799804517836
# 	    |∆| = 1.6560400127480908
# Optimization step 7 :
# 	 Energy = -60.91381235317554
# 	    |∆| = 0.6509420674294102
# Optimization step 8 :
# 	 Energy = -60.776589444216654
# 	    |∆| = 1.5188635000619635
# Optimization step 9 :
# 	 Energy = -60.962208741625695
# 	    |∆| = 0.4037708424519871
# Optimization step 10:
# 	 Energy = -60.977119401975955
# 	    |∆| = 1.0042797685697122
# Optimization step 11:
# 	 Energy = -60.99225879459097
# 	    |∆| = 0.5289634085323407
# Optimization step 12:
# 	 Energy = -61.04154330665714
# 	    |∆| = 0.49147908026156994
# Optimization step 13:
# 	 Energy = -60.86368271691862
# 	    |∆| = 1.7227179858577477
# Optimization step 14:
# 	 Energy = -61.07043349746143
# 	    |∆| = 0.7170681406522524
# Optimization step 15:
# 	 Energy = -61.178059040849874
# 	    |∆| = 0.6553330385111289
# Optimization step 16:
# 	 Energy = -61.18515902080517
# 	    |∆| = 0.9729622861127334
# Optimization step 17:
# 	 Energy = -61.2369812406633
# 	    |∆| = 0.4445310446725016
# Optimization step 18:
# 	 Energy = -61.271530733911405
# 	    |∆| = 0.3944313374872988
# Optimization step 19:
# 	 Energy = -61.27983403548491
# 	    |∆| = 0.25866919934358257
# We are using "SLSQP" now.
# VQE simulation commencing...
#
# Optimization step 0 :
# 	 Energy = -59.0544269273677
# 	    |∆| = 2.6008017884409314
# Optimization step 1 :
# 	 Energy = -58.99793364229616
# Optimization step 2 :
# 	 Energy = -60.17764439148184
# 	    |∆| = 1.7577741277286507
# Optimization step 3 :
# 	 Energy = -59.26563591399989
# Optimization step 4 :
# 	 Energy = -60.309914791656865
# 	    |∆| = 1.8578284656882855
# Optimization step 5 :
# 	 Energy = -60.78551351127259
# 	    |∆| = 1.8597767482891883
# Optimization step 6 :
# 	 Energy = -59.081604453192156
# Optimization step 7 :
# 	 Energy = -60.909936520587515
# 	    |∆| = 1.0513790930514517
# Optimization step 8 :
# 	 Energy = -60.69564161556974
# Optimization step 9 :
# 	 Energy = -61.01782505607029
# 	    |∆| = 0.6255422331368432
# Optimization step 10:
# 	 Energy = -60.98046863287883
# Optimization step 11:
# 	 Energy = -61.07605853096168
# 	    |∆| = 0.4983755814931161
# Optimization step 12:
# 	 Energy = -61.03239869936386
# Optimization step 13:
# 	 Energy = -61.150192117300094
# 	    |∆| = 0.6969085139155957
# Optimization step 14:
# 	 Energy = -60.530856554272084
# Optimization step 15:
# 	 Energy = -61.196580199366224
# 	    |∆| = 0.8483414968565794
# Optimization step 16:
# 	 Energy = -60.99551514557931
# Optimization step 17:
# 	 Energy = -61.23846589908093
# 	    |∆| = 0.8173385635768564
# We are using "NaturalGradient" now.
# Optimization step 0 :
# 	 Energy = -59.0544269273677 	 |∆| = 0.3844735089499007
# Optimization step 1 :
# 	 Energy = -59.151772051343414 	 |∆| = 0.40573131622923986
# Optimization step 2 :
# 	 Energy = -59.248911704615175 	 |∆| = 0.4299434325675709
# Optimization step 3 :
# 	 Energy = -59.345812890107425 	 |∆| = 0.4576638998535015
# Optimization step 4 :
# 	 Energy = -59.44254608946679 	 |∆| = 0.4888830606547708
# Optimization step 5 :
# 	 Energy = -59.539097337992594 	 |∆| = 0.5238920085664318
# Optimization step 6 :
# 	 Energy = -59.635506298650434 	 |∆| = 0.5626885896445607
# Optimization step 7 :
# 	 Energy = -59.73185460307311 	 |∆| = 0.6050475267474441
# Optimization step 8 :
# 	 Energy = -59.82816716783049 	 |∆| = 0.6512014476504275
# Optimization step 9 :
# 	 Energy = -59.92437036458244 	 |∆| = 0.7023704402787586
# Optimization step 10:
# 	 Energy = -60.02041274048545 	 |∆| = 0.7602170228980923
# Optimization step 11:
# 	 Energy = -60.116180291078855 	 |∆| = 0.8276429901623158
# Optimization step 12:
# 	 Energy = -60.21150716394415 	 |∆| = 0.9090303530789607
# Optimization step 13:
# 	 Energy = -60.30623746528136 	 |∆| = 1.0094804332919776
# Optimization step 14:
# 	 Energy = -60.400442224891506 	 |∆| = 1.129465721033287
# Optimization step 15:
# 	 Energy = -60.494685155433736 	 |∆| = 1.2483044166015034
# Optimization step 16:
# 	 Energy = -60.59119081715395 	 |∆| = 1.2993888180735282
# Optimization step 17:
# 	 Energy = -60.691228181022886 	 |∆| = 1.2815555614963774
# Optimization step 18:
# 	 Energy = -60.78965869943562 	 |∆| = 1.339999183785149
# Optimization step 19:
# 	 Energy = -60.8809354843073 	 |∆| = 1.6633753006933436
# Optimization step 20:
# 	 Energy = -60.955334890898406 	 |∆| = 3.3535772434445486
# Optimization step 21:
# 	 Energy = -60.95988360323453 	 |∆| = 1.7508615380135566
# Optimization step 22:
# 	 Energy = -61.003076355372585 	 |∆| = 2.318949155094887
# Optimization step 23:
# 	 Energy = -60.95048864185819 	 |∆| = 0.6999222036442835
# Optimization step 24:
# 	 Energy = -61.02986547467814 	 |∆| = 1.167956388808403
# Optimization step 25:
# 	 Energy = -61.08083903006697 	 |∆| = 2.0218509314410102
# Optimization step 26:
# 	 Energy = -61.14625792059158 	 |∆| = 1.3166739877893607
# Optimization step 27:
# 	 Energy = -61.19276488272583 	 |∆| = 1.8714595019686053
# Optimization step 28:
# 	 Energy = -61.211943176934675 	 |∆| = 1.2394943177432927
# Optimization step 29:
# 	 Energy = -61.24802691668875 	 |∆| = 2.6479080398901043
# Optimization step 30:
# 	 Energy = -61.11191968737284 	 |∆| = 0.5716225443186623
# Optimization step 31:
# 	 Energy = -61.19715065936524 	 |∆| = 0.8135094017493872
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 16
#      14 if method == 'NaturalGradient':
#      15     print(f'We are using "{method}" now.')
# ---> 16     result, history = adapt.run_with_gradient_descent(x0 = x_random, max_steps=50, learning_rate= 0.1)  # 这里设置最大步数为100
#      17 else:
#      18     # 运行ADAPT_VQE中的方法
#      19     print(f'We are using "{method}" now.')
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:456, in run_with_gradient_descent(self, x0, max_steps, learning_rate, clip_value)
#     446 vqe_history['params'][counter] = tuple(params)
#     447 vqe_history['energy'][counter] = energy
#     449 # # 如果能量上升则提前停止
#     450 # if energy > prev_energy:
#     451 #     print(f"由于能量上升，在第 {step} 步提前停止。")
#     452 #     break
#     453
#     454 # # 更新prev_energy为当前的能量值
#     455 # prev_energy = energy
# --> 456
#     457 # 计算梯度
#     458 grad = self.natural_gradient(params)
#     459 print(f"第 {step} 步的梯度: {grad}")
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:298, in VQE_Driver.natural_gradient(self, x)
#     297 def natural_gradient(self, x: np.array) -> np.array:
# --> 298     fisher_information_matrix = self.compute_fisher_information(x)
#     300     # 正则化
#     301     regularization_strength = 1e-5
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:264, in VQE_Driver.compute_fisher_information(self, x)
#     261 for j in range(num_parameters):
#     262     # 计算偏导数
#     263     partial_i = self.evaluate_partial_derivative(x, i)
# --> 264     partial_j = self.evaluate_partial_derivative(x, j)
#     266     # 计算费舍尔信息矩阵的元素
#     267     fisher_information[i, j] = partial_i * partial_j
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:291, in VQE_Driver.evaluate_partial_derivative(self, x, param_index, delta)
#     288 x_minus[param_index] -= delta
#     290 # 计算期望值
# --> 291 f_plus = self.f(x_plus)
#     292 f_minus = self.f(x_minus)
#     294 # 使用中心差分法计算偏导数
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:207, in VQE_Driver.f(self, x)
#     205 else:
#     206     state = self.get_state(self.circuit, x)
# --> 207 return self._f(self.observable, state)
#
# File ~/Downloads/QMMMbed-main/nbed/variational_optimization.py:189, in VQE_Driver._f(self, observable, state)
#     187     return observable.expval(state).real
#     188 elif self.expectation_eval == 'symbolic_direct':
# --> 189     return (state.dagger * observable * state).real
#     190 elif self.expectation_eval == 'observable_rotation':
#     191     return (self.ref_state.dagger * observable.perform_rotations(state) * self.ref_state).real
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py:1826, in QuantumState.__mul__(self, mul_obj)
#    1824     new_state_op = self.state_op * mul_obj
#    1825     new_state_op.coeff_vec*=((-1j)**new_state_op.Y_count)
# -> 1826     new_bra_state = QuantumState(
#    1827         new_state_op.X_block,
#    1828         new_state_op.coeff_vec,
#    1829         vec_type='bra'
#    1830     )
#    1831     return new_bra_state.cleanup()
#    1833 else:
#
# File ~/.virtualenvs/QMMMbed-main/lib/python3.8/site-packages/symmer/operators/base.py:1614, in QuantumState.__init__(self, state_matrix, coeff_vector, vec_type)
#    1612     state_matrix = state_matrix.reshape([1,-1])
#    1613 state_matrix = state_matrix.astype(int) # in case input is boolean
# -> 1614 assert(set(state_matrix.flatten()).issubset({0,1})) # must be binary, does not support N-ary qubits
#    1615 self.n_terms, self.n_qubits = state_matrix.shape
#    1616 self.state_matrix = state_matrix
#
# KeyboardInterrupt:

# %% [markdown]
# and we may plot the convergence:

# %%
from matplotlib import pyplot as plt

fig, axis = plt.subplots()
fig.tight_layout()
Y_adapt = [embed_mol.embedded_scf.e_tot]
X_adapt = [0]

# niter = len(out['interim_data']['history'])
niter=len(adapt_result['interim_data'].keys())-1
offset=0
prev = 0
colors=[]
for i in range(1,niter+1):
    c = plt.cm.plasma_r(i/niter)
    colors.append(c)
    # i = str(i)
    # params   = out['interim_data'][i]['history']['params']
    energy   = adapt_result['interim_data'][i]['history']['energy']
    gradient = adapt_result['interim_data'][i]['history']['gradient']
    X, Y = zip(*energy.items())
    Y = np.array(Y)
    X = offset+np.array([int(x) for x in X])
    axis.plot(X, abs(Y+emb_corr-e_pbe), lw=1.2, zorder=10, color=c)
    grad_norm = np.linalg.norm(list(gradient.values()), axis=1)
    offset+=(len(X)-1)
    X_adapt.append(offset)
    Y_adapt.append(adapt_result['interim_data'][i]['output']['fun'])

axis.plot(
    X_adapt, abs(np.array(Y_adapt)+emb_corr-e_pbe), ms=5,
    ls=':', color='black', marker='d', label='ADAPT energy after\neach VQE routine', zorder=10, lw=1
)

axis.set_ylabel('Error from target embedding energy [Ha]')
axis.set_xlabel('Optimization step')
axis.set_yscale('log')
axis.legend()
axis.grid()
plt.show()

# %% [markdown]
# You can see that, at each step, ADAPT selects one of the CCSD excitations, appends it to a growing circuit, and reoptimizes the variational parameters through VQE. The final set of excitation generators is:

# %%
print(adapt_result['adapt_operator'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 print(adapt_result['adapt_operator'])
#
# NameError: name 'adapt_result' is not defined

# %% [markdown]
# With corresponding quantum circuit:

# %%
qc = PauliwordOp_to_QuantumCircuit(
    PauliwordOp.from_list(adapt_result['adapt_operator']), 
    bind_params=False,
    include_barriers=False
)
qc.draw()
# Out:
#       ┌───┐                                               ┌───┐ ┌─────┐┌───┐»
# q_0: ─┤ H ├───■───────────────────────────────────────■───┤ H ├─┤ Sdg ├┤ H ├»
#       ├───┤ ┌─┴─┐                                   ┌─┴─┐ ├───┤ ├─────┤├───┤»
# q_1: ─┤ H ├─┤ X ├──■─────────────────────────────■──┤ X ├─┤ H ├─┤ Sdg ├┤ H ├»
#      ┌┴───┴┐├───┤  │                             │  └───┘ └───┘ └─────┘└───┘»
# q_2: ┤ Sdg ├┤ H ├──┼────■────────────────────────┼──────────────────────────»
#      └┬───┬┘└───┘  │  ┌─┴─┐                      │                          »
# q_3: ─┤ H ├────────┼──┤ X ├──────────────────────┼───────────────────────■──»
#      ┌┴───┴┐┌───┐  │  └───┘                      │                       │  »
# q_4: ┤ Sdg ├┤ H ├──┼─────────────────────────────┼───────────────────────┼──»
#      ├─────┤├───┤  │                             │                       │  »
# q_5: ┤ Sdg ├┤ H ├──┼─────────────────────────────┼───────────────────────┼──»
#      └┬───┬┘└───┘  │                             │                       │  »
# q_6: ─┤ H ├────────┼─────────────────────────────┼───────────────────────┼──»
#       ├───┤      ┌─┴─┐                         ┌─┴─┐┌───┐┌─────┐ ┌───┐ ┌─┴─┐»
# q_7: ─┤ H ├──────┤ X ├──■───────────────────■──┤ X ├┤ H ├┤ Sdg ├─┤ H ├─┤ X ├»
#      ┌┴───┴┐┌───┐└───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤├───┤├─────┤ ├───┤ └───┘»
# q_8: ┤ Sdg ├┤ H ├─────┤ X ├┤ Rz(-2*P[0]) ├┤ X ├┤ H ├┤ S ├┤ Sdg ├─┤ H ├──────»
#      └─────┘└───┘     └───┘└─────────────┘└───┘└───┘└───┘└─────┘ └───┘      »
# «                                                                   ┌───┐»
# «q_0: ──■───────────────────────────────────────────────────────■───┤ H ├»
# «     ┌─┴─┐                                                   ┌─┴─┐ ├───┤»
# «q_1: ┤ X ├───────■───────────────────────────────────────■───┤ X ├─┤ H ├»
# «     └───┘       │                                       │   ├───┤ ├───┤»
# «q_2: ────────────┼──────────────────────────────────■────┼───┤ H ├─┤ S ├»
# «                 │                                ┌─┴─┐  │   ├───┤ ├───┤»
# «q_3: ────────────┼─────────────────────────────■──┤ X ├──┼───┤ H ├─┤ H ├»
# «                 │                             │  └───┘  │   └───┘ └───┘»
# «q_4: ────────────┼─────────────────────────────┼─────────┼──────────────»
# «               ┌─┴─┐                           │       ┌─┴─┐ ┌───┐ ┌───┐»
# «q_5: ──────────┤ X ├───────■───────────────────┼────■──┤ X ├─┤ H ├─┤ S ├»
# «               └───┘     ┌─┴─┐┌─────────────┐  │  ┌─┴─┐├───┤┌┴───┴┐├───┤»
# «q_6: ────────────────────┤ X ├┤ Rz(-2*P[1]) ├──┼──┤ X ├┤ H ├┤ Sdg ├┤ H ├»
# «                         └───┘└─────────────┘┌─┴─┐├───┤├───┤└┬───┬┘└───┘»
# «q_7: ──■───────────────────■─────────────────┤ X ├┤ H ├┤ S ├─┤ H ├──────»
# «     ┌─┴─┐┌─────────────┐┌─┴─┐     ┌───┐     ├───┤├───┤└───┘ └───┘      »
# «q_8: ┤ X ├┤ Rz(-2*P[2]) ├┤ X ├─────┤ H ├─────┤ S ├┤ H ├─────────────────»
# «     └───┘└─────────────┘└───┘     └───┘     └───┘└───┘                 »
# «      ┌───┐ ┌─────┐┌───┐                                                      »
# «q_0: ─┤ S ├─┤ Sdg ├┤ H ├──■───────────────────────────────────────────────────»
# «      ├───┤ └─────┘└───┘┌─┴─┐                                                 »
# «q_1: ─┤ S ├─────────────┤ X ├─────────────────────────────────────────────────»
# «     ┌┴───┴┐ ┌───┐      └───┘                                    ┌───┐  ┌───┐ »
# «q_2: ┤ Sdg ├─┤ H ├───■───────────────────────────────────────■───┤ H ├──┤ S ├─»
# «     └─────┘ └───┘ ┌─┴─┐                                   ┌─┴─┐ ├───┤ ┌┴───┴┐»
# «q_3: ──────────────┤ X ├──■─────────────────────────────■──┤ X ├─┤ H ├─┤ Sdg ├»
# «                   └───┘  │                             │  └───┘ └───┘ └─────┘»
# «q_4: ─────────────────────┼─────────────────────────────┼─────────────────────»
# «     ┌─────┐ ┌───┐      ┌─┴─┐                         ┌─┴─┐┌───┐ ┌───┐ ┌─────┐»
# «q_5: ┤ Sdg ├─┤ H ├──────┤ X ├──■───────────────────■──┤ X ├┤ H ├─┤ S ├─┤ Sdg ├»
# «     └─────┘ └───┘      └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤├───┤┌┴───┴┐└┬───┬┘»
# «q_6: ────────────────────────┤ X ├┤ Rz(-2*P[3]) ├┤ X ├┤ H ├┤ S ├┤ Sdg ├─┤ H ├─»
# «                             └───┘└─────────────┘└───┘└───┘└───┘└─────┘ └───┘ »
# «q_7: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_8: ─────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «                                                                            »
# «q_0: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_1: ───────────────────────────────────────────────────────────────────────»
# «     ┌─────┐┌───┐                                               ┌───┐ ┌───┐ »
# «q_2: ┤ Sdg ├┤ H ├──■────────────────────────────────────────■───┤ H ├─┤ S ├─»
# «     └┬───┬┘└───┘┌─┴─┐                                    ┌─┴─┐ ├───┤ ├───┤ »
# «q_3: ─┤ H ├──────┤ X ├──■─────────────────────────────■───┤ X ├─┤ H ├─┤ S ├─»
# «      └───┘      └───┘  │                             │   └───┘ └───┘ └───┘ »
# «q_4: ───────────────────┼─────────────────────────────┼─────────────────────»
# «      ┌───┐             │                             │                     »
# «q_5: ─┤ H ├─────────────┼─────────────────────────────┼─────────────────────»
# «      └───┘           ┌─┴─┐                         ┌─┴─┐ ┌───┐ ┌───┐┌─────┐»
# «q_6: ─────────────────┤ X ├──■───────────────────■──┤ X ├─┤ H ├─┤ S ├┤ Sdg ├»
# «                      └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤┌┴───┴┐├───┤└─────┘»
# «q_7: ──────────────────────┤ X ├┤ Rz(-2*P[4]) ├┤ X ├┤ H ├┤ Sdg ├┤ H ├───────»
# «                           └───┘└─────────────┘└───┘└───┘└─────┘└───┘       »
# «q_8: ───────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                   ┌───┐┌───┐»
# «q_0: ──────────────────────────────────────────────────────────■───┤ H ├┤ S ├»
# «                                                             ┌─┴─┐ └───┘└───┘»
# «q_1: ──■─────────────────────────────────────────────────■───┤ X ├───────────»
# «     ┌─┴─┐                                             ┌─┴─┐ └───┘           »
# «q_2: ┤ X ├──■───────────────────────────────────────■──┤ X ├─────────────────»
# «     ├───┤┌─┴─┐                                   ┌─┴─┐├───┤ ┌───┐           »
# «q_3: ┤ H ├┤ X ├──■─────────────────────────────■──┤ X ├┤ H ├─┤ H ├───────────»
# «     └───┘└───┘  │                             │  └───┘└───┘ └───┘           »
# «q_4: ────────────┼─────────────────────────────┼─────────────────────────────»
# «                 │                             │                             »
# «q_5: ────────────┼─────────────────────────────┼─────────────────────────────»
# «     ┌───┐     ┌─┴─┐                         ┌─┴─┐┌───┐┌───┐┌─────┐┌───┐     »
# «q_6: ┤ H ├─────┤ X ├──■───────────────────■──┤ X ├┤ H ├┤ S ├┤ Sdg ├┤ H ├─────»
# «     └───┘     └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤├───┤└───┘└─────┘└───┘     »
# «q_7: ───────────────┤ X ├┤ Rz(-2*P[5]) ├┤ X ├┤ H ├┤ S ├──────────────────────»
# «                    └───┘└─────────────┘└───┘└───┘└───┘                      »
# «q_8: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «     ┌─────┐┌───┐                                                            »
# «q_0: ┤ Sdg ├┤ H ├──■─────────────────────────────────────────────────────────»
# «     └─────┘└───┘┌─┴─┐                                                       »
# «q_1: ────────────┤ X ├──■─────────────────────────────────────────────────■──»
# «                 └───┘┌─┴─┐                                             ┌─┴─┐»
# «q_2: ─────────────────┤ X ├──■───────────────────────────────────────■──┤ X ├»
# «                      └───┘┌─┴─┐                                   ┌─┴─┐├───┤»
# «q_3: ──────────────────────┤ X ├──■─────────────────────────────■──┤ X ├┤ H ├»
# «                           └───┘  │                             │  └───┘└───┘»
# «q_4: ─────────────────────────────┼─────────────────────────────┼────────────»
# «                                ┌─┴─┐                         ┌─┴─┐┌───┐┌───┐»
# «q_5: ───────────────────────────┤ X ├──■───────────────────■──┤ X ├┤ H ├┤ S ├»
# «                                └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤├───┤└───┘»
# «q_6: ────────────────────────────────┤ X ├┤ Rz(-2*P[6]) ├┤ X ├┤ H ├┤ S ├─────»
# «                                     └───┘└─────────────┘└───┘└───┘└───┘     »
# «q_7: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «q_8: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «            ┌───┐┌───┐┌───┐                                                  »
# «q_0: ───■───┤ H ├┤ S ├┤ H ├──────────────────────────────────────────────────»
# «      ┌─┴─┐ ├───┤└───┘└───┘                                                  »
# «q_1: ─┤ X ├─┤ H ├──■─────────────────────────────────────────────────────────»
# «     ┌┴───┴┐├───┤┌─┴─┐                                                       »
# «q_2: ┤ Sdg ├┤ H ├┤ X ├──■─────────────────────────────────────────────────■──»
# «     ├─────┤├───┤└───┘  │                                                 │  »
# «q_3: ┤ Sdg ├┤ H ├───────┼─────────────────────────────────────────────────┼──»
# «     └─────┘└───┘       │                                                 │  »
# «q_4: ───────────────────┼─────────────────────────────────────────────────┼──»
# «      ┌───┐           ┌─┴─┐                                             ┌─┴─┐»
# «q_5: ─┤ H ├───────────┤ X ├──■───────────────────────────────────────■──┤ X ├»
# «      └───┘           └───┘┌─┴─┐                                   ┌─┴─┐└───┘»
# «q_6: ──────────────────────┤ X ├──■─────────────────────────────■──┤ X ├─────»
# «                           └───┘┌─┴─┐                         ┌─┴─┐└───┘     »
# «q_7: ───────────────────────────┤ X ├──■───────────────────■──┤ X ├──────────»
# «                                └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤┌───┐     »
# «q_8: ────────────────────────────────┤ X ├┤ Rz(-2*P[7]) ├┤ X ├┤ H ├┤ H ├─────»
# «                                     └───┘└─────────────┘└───┘└───┘└───┘     »
# «                                                                            »
# «q_0: ───────────────────────────────────────────────────────────────────────»
# «           ┌───┐ ┌─────┐ ┌───┐                                              »
# «q_1: ──■───┤ H ├─┤ Sdg ├─┤ H ├──────────────────────────────────────────────»
# «     ┌─┴─┐ ├───┤ └┬───┬┘┌┴───┴┐┌───┐                                        »
# «q_2: ┤ X ├─┤ H ├──┤ S ├─┤ Sdg ├┤ H ├──■─────────────────────────────────────»
# «     └───┘ └───┘  └───┘ └─────┘└───┘┌─┴─┐                                   »
# «q_3: ───────────────────────────────┤ X ├──■────────────────────────────────»
# «                                    └───┘  │                                »
# «q_4: ──────────────────────────────────────┼────────────────────────────────»
# «     ┌───┐┌─────┐ ┌───┐                  ┌─┴─┐                              »
# «q_5: ┤ H ├┤ Sdg ├─┤ H ├──────────────────┤ X ├──■───────────────────────────»
# «     └───┘└─────┘ └───┘                  └───┘┌─┴─┐                         »
# «q_6: ─────────────────────────────────────────┤ X ├──■──────────────────────»
# «                                              └───┘┌─┴─┐                    »
# «q_7: ──────────────────────────────────────────────┤ X ├──■─────────────────»
# «                                                   └───┘┌─┴─┐┌─────────────┐»
# «q_8: ───────────────────────────────────────────────────┤ X ├┤ Rz(-2*P[8]) ├»
# «                                                        └───┘└─────────────┘»
# «                                                                    »
# «q_0: ───────────────────────────────────────────────────────────────»
# «                                                                    »
# «q_1: ──────────────────────────────────────────────────■────────────»
# «                                  ┌───┐ ┌───┐  ┌───┐ ┌─┴─┐          »
# «q_2: ──────────────────────────■──┤ H ├─┤ S ├──┤ H ├─┤ X ├──■───────»
# «                             ┌─┴─┐├───┤ ├───┤ ┌┴───┴┐├───┤  │       »
# «q_3: ────────────────────■───┤ X ├┤ H ├─┤ S ├─┤ Sdg ├┤ H ├──┼───────»
# «                         │   └───┘└───┘ └───┘ └─────┘└───┘  │       »
# «q_4: ────────────────────┼──────────────────────────────────┼───────»
# «                       ┌─┴─┐ ┌───┐┌───┐┌─────┐ ┌───┐      ┌─┴─┐     »
# «q_5: ─────────────■────┤ X ├─┤ H ├┤ S ├┤ Sdg ├─┤ H ├──────┤ X ├──■──»
# «                ┌─┴─┐ ┌┴───┴┐├───┤└───┘└─────┘ └───┘      └───┘┌─┴─┐»
# «q_6: ───────■───┤ X ├─┤ Sdg ├┤ H ├─────────────────────────────┤ X ├»
# «          ┌─┴─┐ └───┘ └─────┘└───┘                             └───┘»
# «q_7: ──■──┤ X ├─────────────────────────────────────────────────────»
# «     ┌─┴─┐├───┤┌─────┐ ┌───┐                                        »
# «q_8: ┤ X ├┤ H ├┤ Sdg ├─┤ H ├────────────────────────────────────────»
# «     └───┘└───┘└─────┘ └───┘                                        »
# «                                                                             »
# «q_0: ────────────────────────────────────────────■───────────────────────────»
# «                                   ┌───┐ ┌───┐ ┌─┴─┐                         »
# «q_1: ───────────────────────────■──┤ H ├─┤ S ├─┤ X ├──■──────────────────────»
# «                              ┌─┴─┐├───┤ └───┘ └───┘┌─┴─┐                    »
# «q_2: ──────────────────────■──┤ X ├┤ H ├────────────┤ X ├──■─────────────────»
# «                           │  └───┘└───┘            └───┘┌─┴─┐               »
# «q_3: ──────────────────────┼─────────────────────────────┤ X ├──■────────────»
# «                           │                             └───┘  │            »
# «q_4: ──────────────────────┼────────────────────────────────────┼────────────»
# «                         ┌─┴─┐┌───┐┌───┐┌─────┐┌───┐          ┌─┴─┐          »
# «q_5: ─────────────────■──┤ X ├┤ H ├┤ S ├┤ Sdg ├┤ H ├──────────┤ X ├──■───────»
# «     ┌─────────────┐┌─┴─┐├───┤├───┤└───┘└─────┘└───┘          └───┘┌─┴─┐     »
# «q_6: ┤ Rz(-2*P[9]) ├┤ X ├┤ H ├┤ S ├────────────────────────────────┤ X ├──■──»
# «     └─────────────┘└───┘└───┘└───┘                                └───┘┌─┴─┐»
# «q_7: ───────────────────────────────────────────────────────────────────┤ X ├»
# «                                                                        └───┘»
# «q_8: ────────────────────────────────────────────────────────────────────────»
# «                                                                             »
# «                                                              ┌───┐ ┌───┐     »
# «q_0: ─────────────────────────────────────────────────────■───┤ H ├─┤ H ├─────»
# «                                                        ┌─┴─┐┌┴───┴┐├───┤     »
# «q_1: ────────────────────────────────────────────────■──┤ X ├┤ Sdg ├┤ H ├──■──»
# «                                                   ┌─┴─┐├───┤└─────┘└───┘┌─┴─┐»
# «q_2: ───────────────────────────────────────────■──┤ X ├┤ H ├────────────┤ X ├»
# «                                              ┌─┴─┐├───┤├───┤┌─────┐┌───┐└───┘»
# «q_3: ──────────────────────────────────────■──┤ X ├┤ H ├┤ S ├┤ Sdg ├┤ H ├─────»
# «                                           │  └───┘└───┘└───┘└─────┘└───┘     »
# «q_4: ──────────────────────────────────────┼──────────────────────────────────»
# «                                         ┌─┴─┐┌───┐┌───┐                      »
# «q_5: ─────────────────────────────────■──┤ X ├┤ H ├┤ S ├──────────────────────»
# «                                    ┌─┴─┐├───┤└───┘└───┘                      »
# «q_6: ────────────────────────────■──┤ X ├┤ H ├────────────────────────────────»
# «                               ┌─┴─┐├───┤└───┘                                »
# «q_7: ──■────────────────────■──┤ X ├┤ H ├─────────────────────────────────────»
# «     ┌─┴─┐┌──────────────┐┌─┴─┐├───┤├───┤┌───┐                                »
# «q_8: ┤ X ├┤ Rz(-2*P[10]) ├┤ X ├┤ H ├┤ S ├┤ H ├────────────────────────────────»
# «     └───┘└──────────────┘└───┘└───┘└───┘└───┘                                »
# «                                                                              »
# «q_0: ─────────────────────────────────────────────────────────────────────────»
# «                                              ┌───┐ ┌───┐ ┌───┐               »
# «q_1: ──────────────────────────────────────■──┤ H ├─┤ S ├─┤ H ├──■────────────»
# «                                         ┌─┴─┐├───┤┌┴───┴┐├───┤┌─┴─┐          »
# «q_2: ──■──────────────────────────────■──┤ X ├┤ H ├┤ Sdg ├┤ H ├┤ X ├──■───────»
# «       │                              │  └───┘└───┘└─────┘└───┘└───┘  │       »
# «q_3: ──┼──────────────────────────────┼───────────────────────────────┼───────»
# «       │                              │                               │       »
# «q_4: ──┼──────────────────────────────┼───────────────────────────────┼───────»
# «       │                              │                               │       »
# «q_5: ──┼──────────────────────────────┼───────────────────────────────┼───────»
# «     ┌─┴─┐                          ┌─┴─┐┌───┐                        │       »
# «q_6: ┤ X ├──■────────────────────■──┤ X ├┤ H ├────────────────────────┼───────»
# «     └───┘┌─┴─┐┌──────────────┐┌─┴─┐├───┤├───┤                      ┌─┴─┐     »
# «q_7: ─────┤ X ├┤ Rz(-2*P[11]) ├┤ X ├┤ H ├┤ H ├──────────────────────┤ X ├──■──»
# «          └───┘└──────────────┘└───┘└───┘└───┘                      └───┘┌─┴─┐»
# «q_8: ────────────────────────────────────────────────────────────────────┤ X ├»
# «                                                                         └───┘»
# «                                                                      »
# «q_0: ──────────────────────────────────────────■──────────────────────»
# «                                       ┌───┐ ┌─┴─┐                    »
# «q_1: ─────────────────────────────■────┤ H ├─┤ X ├──■─────────────────»
# «                                ┌─┴─┐  ├───┤ ├───┤┌─┴─┐               »
# «q_2: ───────────────────────■───┤ X ├──┤ H ├─┤ S ├┤ X ├──■────────────»
# «                            │   └───┘  └───┘ └───┘└───┘┌─┴─┐          »
# «q_3: ───────────────────────┼──────────────────────────┤ X ├──■───────»
# «                            │                          └───┘  │       »
# «q_4: ───────────────────────┼─────────────────────────────────┼───────»
# «                            │                                 │       »
# «q_5: ───────────────────────┼─────────────────────────────────┼───────»
# «                            │                                 │       »
# «q_6: ───────────────────────┼─────────────────────────────────┼───────»
# «                          ┌─┴─┐ ┌───┐ ┌─────┐┌───┐          ┌─┴─┐     »
# «q_7: ──────────────────■──┤ X ├─┤ H ├─┤ Sdg ├┤ H ├──────────┤ X ├──■──»
# «     ┌──────────────┐┌─┴─┐├───┤┌┴───┴┐└┬───┬┘└───┘          └───┘┌─┴─┐»
# «q_8: ┤ Rz(-2*P[12]) ├┤ X ├┤ H ├┤ Sdg ├─┤ H ├─────────────────────┤ X ├»
# «     └──────────────┘└───┘└───┘└─────┘ └───┘                     └───┘»
# «                                                 ┌───┐                »
# «q_0: ───────────────────────────────────────■────┤ H ├────────────────»
# «                                          ┌─┴─┐  └───┘                »
# «q_1: ─────────────────────────────────■───┤ X ├───────────────────────»
# «                                    ┌─┴─┐┌┴───┴┐ ┌───┐                »
# «q_2: ────────────────────────────■──┤ X ├┤ Sdg ├─┤ H ├────────■───────»
# «                               ┌─┴─┐├───┤└┬───┬┘┌┴───┴┐┌───┐┌─┴─┐     »
# «q_3: ───────────────────────■──┤ X ├┤ H ├─┤ S ├─┤ Sdg ├┤ H ├┤ X ├──■──»
# «                            │  └───┘└───┘ └───┘ └─────┘└───┘└───┘┌─┴─┐»
# «q_4: ───────────────────────┼────────────────────────────────────┤ X ├»
# «                            │                                    └───┘»
# «q_5: ───────────────────────┼─────────────────────────────────────────»
# «                            │                                         »
# «q_6: ───────────────────────┼─────────────────────────────────────────»
# «                          ┌─┴─┐┌───┐┌───┐                             »
# «q_7: ──────────────────■──┤ X ├┤ H ├┤ S ├─────────────────────────────»
# «     ┌──────────────┐┌─┴─┐├───┤├───┤└───┘                             »
# «q_8: ┤ Rz(-2*P[13]) ├┤ X ├┤ H ├┤ S ├──────────────────────────────────»
# «     └──────────────┘└───┘└───┘└───┘                                  »
# «
# «q_0: ────────────────────────────────────
# «
# «q_1: ────────────────────────────────────
# «                               ┌───┐┌───┐
# «q_2: ───────────────────────■──┤ H ├┤ S ├
# «                          ┌─┴─┐├───┤├───┤
# «q_3: ──────────────────■──┤ X ├┤ H ├┤ S ├
# «     ┌──────────────┐┌─┴─┐├───┤├───┤└───┘
# «q_4: ┤ Rz(-2*P[14]) ├┤ X ├┤ H ├┤ S ├─────
# «     └──────────────┘└───┘└───┘└───┘
# «q_5: ────────────────────────────────────
# «
# «q_6: ────────────────────────────────────
# «
# «q_7: ────────────────────────────────────
# «
# «q_8: ────────────────────────────────────
# «

# %% [markdown]
# You can then start applying circuit optimization techniques to reduce the depth, for example using Qiskit's transpiler with ``optimization_level=3``:

# %%
from qiskit import transpile
qc.depth(), transpile(qc, optimization_level=3).depth()
# Out:
# (159, 120)
